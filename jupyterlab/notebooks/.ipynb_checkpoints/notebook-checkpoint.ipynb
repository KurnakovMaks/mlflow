# %%
pip install huggingface_hub
# Out:
# Requirement already satisfied: huggingface_hub in /opt/conda/lib/python3.11/site-packages (0.34.4)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.11/site-packages (from huggingface_hub) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.11/site-packages (from huggingface_hub) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /opt/conda/lib/python3.11/site-packages (from huggingface_hub) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.11/site-packages (from huggingface_hub) (6.0.1)
# Requirement already satisfied: requests in /opt/conda/lib/python3.11/site-packages (from huggingface_hub) (2.32.4)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/conda/lib/python3.11/site-packages (from huggingface_hub) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.11/site-packages (from huggingface_hub) (4.8.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /opt/conda/lib/python3.11/site-packages (from huggingface_hub) (1.1.7)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests->huggingface_hub) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests->huggingface_hub) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests->huggingface_hub) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests->huggingface_hub) (2023.7.22)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !huggingface-cli login --token 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
# Out:
# ⚠️  Warning: 'huggingface-cli login' is deprecated. Use 'hf auth login' instead.
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `hf`CLI if you want to set the git credential as well.
# Token is valid (permission: write).
# The token `2025-08-12` has been saved to /home/jovyan/.cache/huggingface/stored_tokens
# Your token has been saved to /home/jovyan/.cache/huggingface/token
# Login successful.
# The current active token is: `2025-08-12`

# %%
from datasets import load_dataset
import os

# %%
dataset = load_dataset('csv', data_files={'train': "data/train.csv",'test': "data/test.csv",'sample_submission': "data/sample_submission.csv"})

# %%
dataset.push_to_hub("aijk2")
# Out:
# Uploading the dataset shards:   0%|          | 0/20 [00:00<?, ? shards/s]
# Creating parquet from Arrow format:   0%|          | 0/2020 [00:00<?, ?ba/s]
# Creating parquet from Arrow format:   2%|▏         | 37/2020 [00:00<00:05, 364.02ba/s]
# Creating parquet from Arrow format:   4%|▎         | 74/2020 [00:00<00:05, 329.07ba/s]
# Creating parquet from Arrow format:   6%|▌         | 115/2020 [00:00<00:05, 361.24ba/s]
# Creating parquet from Arrow format:   8%|▊         | 169/2020 [00:00<00:04, 425.86ba/s]
# Creating parquet from Arrow format:  11%|█         | 224/2020 [00:00<00:03, 468.60ba/s]
# Creating parquet from Arrow format:  14%|█▎        | 275/2020 [00:00<00:03, 481.91ba/s]
# Creating parquet from Arrow format:  16%|█▌        | 324/2020 [00:00<00:03, 474.36ba/s]
# Creating parquet from Arrow format:  18%|█▊        | 372/2020 [00:00<00:03, 471.54ba/s]
# Creating parquet from Arrow format:  21%|██        | 420/2020 [00:00<00:03, 445.30ba/s]
# Creating parquet from Arrow format:  23%|██▎       | 465/2020 [00:01<00:03, 431.25ba/s]
# Creating parquet from Arrow format:  25%|██▌       | 509/2020 [00:01<00:03, 431.51ba/s]
# Creating parquet from Arrow format:  27%|██▋       | 553/2020 [00:01<00:03, 431.95ba/s]
# Creating parquet from Arrow format:  30%|██▉       | 601/2020 [00:01<00:03, 444.66ba/s]
# Creating parquet from Arrow format:  32%|███▏      | 646/2020 [00:01<00:03, 436.93ba/s]
# Creating parquet from Arrow format:  34%|███▍      | 690/2020 [00:01<00:03, 433.18ba/s]
# Creating parquet from Arrow format:  36%|███▋      | 734/2020 [00:01<00:02, 428.94ba/s]
# Creating parquet from Arrow format:  39%|███▊      | 779/2020 [00:01<00:02, 433.33ba/s]
# Creating parquet from Arrow format:  41%|████      | 829/2020 [00:01<00:02, 451.33ba/s]
# Creating parquet from Arrow format:  44%|████▎     | 879/2020 [00:01<00:02, 465.29ba/s]
# Creating parquet from Arrow format:  46%|████▌     | 926/2020 [00:02<00:02, 458.76ba/s]
# Creating parquet from Arrow format:  48%|████▊     | 972/2020 [00:02<00:02, 458.92ba/s]
# Creating parquet from Arrow format:  50%|█████     | 1018/2020 [00:02<00:02, 455.62ba/s]
# Creating parquet from Arrow format:  53%|█████▎    | 1067/2020 [00:02<00:02, 462.88ba/s]
# Creating parquet from Arrow format:  55%|█████▌    | 1114/2020 [00:02<00:02, 429.83ba/s]
# Creating parquet from Arrow format:  57%|█████▋    | 1158/2020 [00:02<00:02, 419.34ba/s]
# Creating parquet from Arrow format:  60%|█████▉    | 1202/2020 [00:02<00:01, 422.49ba/s]
# Creating parquet from Arrow format:  62%|██████▏   | 1245/2020 [00:02<00:01, 390.04ba/s]
# Creating parquet from Arrow format:  64%|██████▎   | 1285/2020 [00:02<00:01, 390.34ba/s]
# Creating parquet from Arrow format:  66%|██████▌   | 1329/2020 [00:03<00:01, 402.10ba/s]
# Creating parquet from Arrow format:  68%|██████▊   | 1371/2020 [00:03<00:01, 404.53ba/s]
# Creating parquet from Arrow format:  70%|██████▉   | 1412/2020 [00:03<00:01, 402.41ba/s]
# Creating parquet from Arrow format:  72%|███████▏  | 1455/2020 [00:03<00:01, 410.35ba/s]
# Creating parquet from Arrow format:  74%|███████▍  | 1497/2020 [00:03<00:01, 398.87ba/s]
# Creating parquet from Arrow format:  76%|███████▋  | 1541/2020 [00:03<00:01, 408.69ba/s]
# Creating parquet from Arrow format:  78%|███████▊  | 1583/2020 [00:03<00:01, 403.90ba/s]
# Creating parquet from Arrow format:  80%|████████  | 1624/2020 [00:03<00:00, 396.13ba/s]
# Creating parquet from Arrow format:  82%|████████▏ | 1664/2020 [00:03<00:00, 380.16ba/s]
# Creating parquet from Arrow format:  85%|████████▍ | 1710/2020 [00:04<00:00, 401.30ba/s]
# Creating parquet from Arrow format:  87%|████████▋ | 1755/2020 [00:04<00:00, 414.55ba/s]
# Creating parquet from Arrow format:  89%|████████▉ | 1802/2020 [00:04<00:00, 429.17ba/s]
# Creating parquet from Arrow format:  92%|█████████▏| 1854/2020 [00:04<00:00, 452.92ba/s]
# Creating parquet from Arrow format:  94%|█████████▍| 1900/2020 [00:04<00:00, 446.21ba/s]
# Creating parquet from Arrow format:  96%|█████████▋| 1945/2020 [00:04<00:00, 439.41ba/s]
# Creating parquet from Arrow format: 100%|██████████| 2020/2020 [00:04<00:00, 428.08ba/s]
# Processing Files (0 / 0)                : |          |  0.00B /  0.00B
# New Data Upload                         : |          |  0.00B /  0.00B
#
#                                         :   1%|          |  545kB / 94.5MB
#
# Processing Files (0 / 1)                :   1%|          |  545kB / 94.5MB,  454kB/s
# New Data Upload                         :   1%|          |  545kB / 67.1MB,  454kB/s
#
# Processing Files (0 / 1)                :   1%|          | 1.09MB / 94.5MB,  779kB/s
# New Data Upload                         :   1%|          | 1.09MB / 94.5MB,  779kB/s
#
#                                         :   1%|          | 1.09MB / 94.5MB
#
# Processing Files (0 / 1)                :   2%|▏         | 2.34MB / 94.5MB, 1.30MB/s
# New Data Upload                         :   2%|▏         | 2.34MB / 94.5MB, 1.30MB/s
#
# Processing Files (0 / 1)                :   3%|▎         | 2.89MB / 94.5MB, 1.44MB/s
# New Data Upload                         :   3%|▎         | 2.89MB / 94.5MB, 1.44MB/s
#
#                                         :   3%|▎         | 2.89MB / 94.5MB
#
#                                         :   3%|▎         | 2.89MB / 94.5MB
#
# Processing Files (0 / 1)                :   4%|▍         | 4.06MB / 94.5MB, 1.56MB/s
# New Data Upload                         :   4%|▍         | 4.06MB / 94.5MB, 1.56MB/s
#
#                                         :   4%|▍         | 4.06MB / 94.5MB
#
# Processing Files (0 / 1)                :   5%|▍         | 4.61MB / 94.5MB, 1.54MB/s
# New Data Upload                         :   5%|▍         | 4.61MB / 94.5MB, 1.54MB/s
#
#                                         :   5%|▍         | 4.61MB / 94.5MB
#
# Processing Files (0 / 1)                :   6%|▌         | 5.23MB / 94.5MB, 1.54MB/s
# New Data Upload                         :   6%|▌         | 5.23MB / 94.5MB, 1.54MB/s
#
# Processing Files (0 / 1)                :   6%|▌         | 5.78MB / 94.5MB, 1.60MB/s
# New Data Upload                         :   6%|▌         | 5.78MB / 94.5MB, 1.60MB/s
#
#                                         :   6%|▌         | 5.78MB / 94.5MB
#
# Processing Files (0 / 1)                :   7%|▋         | 6.40MB / 94.5MB, 1.60MB/s
# New Data Upload                         :   7%|▋         | 6.40MB / 94.5MB, 1.60MB/s
#
# Processing Files (0 / 1)                :   7%|▋         | 6.95MB / 94.5MB, 1.65MB/s
# New Data Upload                         :   7%|▋         | 6.95MB / 94.5MB, 1.65MB/s
#
#                                         :   7%|▋         | 6.95MB / 94.5MB
#
#                                         :   7%|▋         | 6.95MB / 94.5MB
#
# Processing Files (0 / 1)                :   8%|▊         | 7.58MB / 94.5MB, 1.58MB/s
# New Data Upload                         :   8%|▊         | 7.58MB / 94.5MB, 1.58MB/s
#
# Processing Files (0 / 1)                :   9%|▊         | 8.12MB / 94.5MB, 1.62MB/s
# New Data Upload                         :   9%|▊         | 8.12MB / 94.5MB, 1.62MB/s
#
# Processing Files (0 / 1)                :   9%|▉         | 8.75MB / 94.5MB, 1.68MB/s
# New Data Upload                         :   9%|▉         | 8.75MB / 94.5MB, 1.68MB/s
#
# Processing Files (0 / 1)                :  10%|▉         | 9.29MB / 94.5MB, 1.72MB/s
# New Data Upload                         :  10%|▉         | 9.29MB / 94.5MB, 1.72MB/s
#
#                                         :  10%|▉         | 9.29MB / 94.5MB
#
#                                         :  10%|▉         | 9.29MB / 94.5MB
#
# Processing Files (0 / 1)                :  10%|█         | 9.92MB / 94.5MB, 1.65MB/s
# New Data Upload                         :  10%|█         | 9.92MB / 94.5MB, 1.65MB/s
#
# Processing Files (0 / 1)                :  11%|█         | 10.5MB / 94.5MB, 1.69MB/s
# New Data Upload                         :  11%|█         | 10.5MB / 94.5MB, 1.69MB/s
#
#                                         :  11%|█         | 10.5MB / 94.5MB
#
#                                         :  11%|█         | 10.5MB / 94.5MB
#
# Processing Files (0 / 1)                :  12%|█▏        | 11.6MB / 94.5MB, 1.71MB/s
# New Data Upload                         :  12%|█▏        | 11.6MB / 94.5MB, 1.71MB/s
#
#                                         :  12%|█▏        | 11.6MB / 94.5MB
#
# Processing Files (0 / 1)                :  13%|█▎        | 12.3MB / 94.5MB, 1.70MB/s
# New Data Upload                         :  13%|█▎        | 12.3MB / 94.5MB, 1.70MB/s
#
# Processing Files (0 / 1)                :  14%|█▎        | 12.8MB / 94.5MB, 1.73MB/s
# New Data Upload                         :  14%|█▎        | 12.8MB / 94.5MB, 1.73MB/s
#
#                                         :  14%|█▎        | 12.8MB / 94.5MB
#
#                                         :  14%|█▎        | 12.8MB / 94.5MB
#
# Processing Files (0 / 1)                :  14%|█▍        | 13.4MB / 94.5MB, 1.68MB/s
# New Data Upload                         :  14%|█▍        | 13.4MB / 94.5MB, 1.68MB/s
#
# Processing Files (0 / 1)                :  15%|█▍        | 14.0MB / 94.5MB, 1.70MB/s
# New Data Upload                         :  15%|█▍        | 14.0MB / 94.5MB, 1.70MB/s
#
#                                         :  15%|█▍        | 14.0MB / 94.5MB
#
#                                         :  15%|█▍        | 14.0MB / 94.5MB
#
# Processing Files (0 / 1)                :  15%|█▌        | 14.6MB / 94.5MB, 1.66MB/s
# New Data Upload                         :  15%|█▌        | 14.6MB / 94.5MB, 1.66MB/s
#
# Processing Files (0 / 1)                :  16%|█▌        | 15.2MB / 94.5MB, 1.68MB/s
# New Data Upload                         :  16%|█▌        | 15.2MB / 94.5MB, 1.68MB/s
#
#                                         :  16%|█▌        | 15.2MB / 94.5MB
#
# Processing Files (0 / 1)                :  17%|█▋        | 15.8MB / 94.5MB, 1.68MB/s
# New Data Upload                         :  17%|█▋        | 15.8MB / 94.5MB, 1.68MB/s
#
#                                         :  17%|█▋        | 15.8MB / 94.5MB
#
# Processing Files (0 / 1)                :  17%|█▋        | 16.3MB / 94.5MB, 1.67MB/s
# New Data Upload                         :  17%|█▋        | 16.3MB / 94.5MB, 1.67MB/s
#
#                                         :  17%|█▋        | 16.3MB / 94.5MB
#
# Processing Files (0 / 1)                :  18%|█▊        | 17.0MB / 94.5MB, 1.66MB/s
# New Data Upload                         :  18%|█▊        | 17.0MB / 94.5MB, 1.66MB/s
#
# Processing Files (0 / 1)                :  19%|█▊        | 17.5MB / 94.5MB, 1.72MB/s
# New Data Upload                         :  19%|█▊        | 17.5MB / 94.5MB, 1.72MB/s
#
#                                         :  19%|█▊        | 17.5MB / 94.5MB
#
#                                         :  19%|█▊        | 17.5MB / 94.5MB
#
# Processing Files (0 / 1)                :  20%|█▉        | 18.7MB / 94.5MB, 1.83MB/s
# New Data Upload                         :  20%|█▉        | 18.7MB / 94.5MB, 1.83MB/s
#
#                                         :  20%|█▉        | 18.7MB / 94.5MB
#
#                                         :  20%|█▉        | 18.7MB / 94.5MB
#
# Processing Files (0 / 1)                :  21%|██        | 19.8MB / 94.5MB, 1.84MB/s
# New Data Upload                         :  21%|██        | 19.8MB / 94.5MB, 1.84MB/s
#
#                                         :  21%|██        | 19.8MB / 94.5MB
#
#                                         :  21%|██        | 19.8MB / 94.5MB
#
# Processing Files (0 / 1)                :  22%|██▏       | 20.5MB / 94.5MB, 1.72MB/s
# New Data Upload                         :  22%|██▏       | 20.5MB / 94.5MB, 1.72MB/s
#
# Processing Files (0 / 1)                :  22%|██▏       | 21.0MB / 94.5MB, 1.78MB/s
# New Data Upload                         :  22%|██▏       | 21.0MB / 94.5MB, 1.78MB/s
#
#                                         :  22%|██▏       | 21.0MB / 94.5MB
#
#                                         :  22%|██▏       | 21.0MB / 94.5MB
#
# Processing Files (0 / 1)                :  23%|██▎       | 22.2MB / 94.5MB, 1.78MB/s
# New Data Upload                         :  23%|██▎       | 22.2MB / 94.5MB, 1.78MB/s
#
#                                         :  23%|██▎       | 22.2MB / 94.5MB
#
#                                         :  23%|██▎       | 22.2MB / 94.5MB
#
# Processing Files (0 / 1)                :  24%|██▍       | 22.7MB / 94.5MB, 1.72MB/s
# New Data Upload                         :  24%|██▍       | 22.7MB / 94.5MB, 1.72MB/s
#
# Processing Files (0 / 1)                :  25%|██▍       | 23.4MB / 94.5MB, 1.72MB/s
# New Data Upload                         :  25%|██▍       | 23.4MB / 94.5MB, 1.72MB/s
#
#                                         :  25%|██▍       | 23.4MB / 94.5MB
#
# Processing Files (0 / 1)                :  25%|██▌       | 24.0MB / 94.5MB, 1.72MB/s
# New Data Upload                         :  25%|██▌       | 24.0MB / 94.5MB, 1.72MB/s
#
# Processing Files (0 / 1)                :  26%|██▌       | 24.5MB / 94.5MB, 1.72MB/s
# New Data Upload                         :  26%|██▌       | 24.5MB / 94.5MB, 1.72MB/s
#
#                                         :  26%|██▌       | 24.5MB / 94.5MB
#
#                                         :  26%|██▌       | 24.5MB / 94.5MB
#
# Processing Files (0 / 1)                :  27%|██▋       | 25.7MB / 94.5MB, 1.78MB/s
# New Data Upload                         :  27%|██▋       | 25.7MB / 94.5MB, 1.78MB/s
#
#                                         :  27%|██▋       | 25.7MB / 94.5MB
#
#                                         :  27%|██▋       | 25.7MB / 94.5MB
#
# Processing Files (0 / 1)                :  28%|██▊       | 26.2MB / 94.5MB, 1.66MB/s
# New Data Upload                         :  28%|██▊       | 26.2MB / 94.5MB, 1.66MB/s
#
# Processing Files (0 / 1)                :  28%|██▊       | 26.9MB / 94.5MB, 1.72MB/s
# New Data Upload                         :  28%|██▊       | 26.9MB / 94.5MB, 1.72MB/s
#
#                                         :  28%|██▊       | 26.9MB / 94.5MB
#
#                                         :  28%|██▊       | 26.9MB / 94.5MB
#
# Processing Files (0 / 1)                :  30%|██▉       | 28.0MB / 94.5MB, 1.72MB/s
# New Data Upload                         :  30%|██▉       | 28.0MB / 94.5MB, 1.72MB/s
#
#                                         :  30%|██▉       | 28.0MB / 94.5MB
#
#                                         :  30%|██▉       | 28.0MB / 94.5MB
#
# Processing Files (0 / 1)                :  30%|███       | 28.6MB / 94.5MB, 1.66MB/s
# New Data Upload                         :  30%|███       | 28.6MB / 94.5MB, 1.66MB/s
#
# Processing Files (0 / 1)                :  31%|███       | 29.2MB / 94.5MB, 1.72MB/s
# New Data Upload                         :  31%|███       | 29.2MB / 94.5MB, 1.72MB/s
#
#                                         :  31%|███       | 29.2MB / 94.5MB
#
# Processing Files (0 / 1)                :  31%|███▏      | 29.8MB / 94.5MB, 1.66MB/s
# New Data Upload                         :  31%|███▏      | 29.8MB / 94.5MB, 1.66MB/s
#
# Processing Files (0 / 1)                :  32%|███▏      | 30.4MB / 94.5MB, 1.72MB/s
# New Data Upload                         :  32%|███▏      | 30.4MB / 94.5MB, 1.72MB/s
#
#                                         :  32%|███▏      | 30.4MB / 94.5MB
#
# Processing Files (0 / 1)                :  33%|███▎      | 30.9MB / 94.5MB, 1.72MB/s
# New Data Upload                         :  33%|███▎      | 30.9MB / 94.5MB, 1.72MB/s
#
# Processing Files (0 / 1)                :  33%|███▎      | 31.6MB / 94.5MB, 1.72MB/s
# New Data Upload                         :  33%|███▎      | 31.6MB / 94.5MB, 1.72MB/s
#
#                                         :  33%|███▎      | 31.6MB / 94.5MB
#
#                                         :  33%|███▎      | 31.6MB / 94.5MB
#
# Processing Files (0 / 1)                :  34%|███▍      | 32.1MB / 94.5MB, 1.72MB/s
# New Data Upload                         :  34%|███▍      | 32.1MB / 94.5MB, 1.72MB/s
#
# Processing Files (0 / 1)                :  35%|███▍      | 32.7MB / 94.5MB, 1.72MB/s
# New Data Upload                         :  35%|███▍      | 32.7MB / 94.5MB, 1.72MB/s
#
#                                         :  35%|███▍      | 32.7MB / 94.5MB
#
# Processing Files (0 / 1)                :  35%|███▌      | 33.3MB / 94.5MB, 1.72MB/s
# New Data Upload                         :  35%|███▌      | 33.3MB / 94.5MB, 1.72MB/s
#
#                                         :  35%|███▌      | 33.3MB / 94.5MB
#
# Processing Files (0 / 1)                :  36%|███▌      | 33.9MB / 94.5MB, 1.72MB/s
# New Data Upload                         :  36%|███▌      | 33.9MB / 94.5MB, 1.72MB/s
#
#                                         :  36%|███▌      | 33.9MB / 94.5MB
#
# Processing Files (0 / 1)                :  37%|███▋      | 35.1MB / 94.5MB, 1.78MB/s
# New Data Upload                         :  37%|███▋      | 35.1MB / 94.5MB, 1.78MB/s
#
#                                         :  37%|███▋      | 35.1MB / 94.5MB
#
#                                         :  37%|███▋      | 35.1MB / 94.5MB
#
# Processing Files (0 / 1)                :  38%|███▊      | 35.6MB / 94.5MB, 1.78MB/s
# New Data Upload                         :  38%|███▊      | 35.6MB / 94.5MB, 1.78MB/s
#
# Processing Files (0 / 1)                :  38%|███▊      | 36.2MB / 94.5MB, 1.72MB/s
# New Data Upload                         :  38%|███▊      | 36.2MB / 94.5MB, 1.72MB/s
#
#                                         :  38%|███▊      | 36.2MB / 94.5MB
#
# Processing Files (0 / 1)                :  39%|███▉      | 36.8MB / 94.5MB, 1.78MB/s
# New Data Upload                         :  39%|███▉      | 36.8MB / 94.5MB, 1.78MB/s
#
#                                         :  39%|███▉      | 36.8MB / 94.5MB
#
# Processing Files (0 / 1)                :  40%|███▉      | 37.4MB / 94.5MB, 1.72MB/s
# New Data Upload                         :  40%|███▉      | 37.4MB / 94.5MB, 1.72MB/s
#
#                                         :  40%|███▉      | 37.4MB / 94.5MB
#
# Processing Files (0 / 1)                :  40%|████      | 38.0MB / 94.5MB, 1.72MB/s
# New Data Upload                         :  40%|████      | 38.0MB / 94.5MB, 1.72MB/s
#
#                                         :  40%|████      | 38.0MB / 94.5MB
#
# Processing Files (0 / 1)                :  41%|████      | 38.6MB / 94.5MB, 1.72MB/s
# New Data Upload                         :  41%|████      | 38.6MB / 94.5MB, 1.72MB/s
#
# Processing Files (0 / 1)                :  41%|████▏     | 39.1MB / 94.5MB, 1.78MB/s
# New Data Upload                         :  41%|████▏     | 39.1MB / 94.5MB, 1.78MB/s
#
#                                         :  41%|████▏     | 39.1MB / 94.5MB
#
# Processing Files (0 / 1)                :  42%|████▏     | 39.8MB / 94.5MB, 1.72MB/s
# New Data Upload                         :  42%|████▏     | 39.8MB / 94.5MB, 1.72MB/s
#
# Processing Files (0 / 1)                :  43%|████▎     | 40.3MB / 94.5MB, 1.78MB/s
# New Data Upload                         :  43%|████▎     | 40.3MB / 94.5MB, 1.78MB/s
#
#                                         :  43%|████▎     | 40.3MB / 94.5MB
#
#                                         :  43%|████▎     | 40.3MB / 94.5MB
#
# Processing Files (0 / 1)                :  44%|████▍     | 41.5MB / 94.5MB, 1.78MB/s
# New Data Upload                         :  44%|████▍     | 41.5MB / 94.5MB, 1.78MB/s
#
#                                         :  44%|████▍     | 41.5MB / 94.5MB
#
#                                         :  44%|████▍     | 41.5MB / 94.5MB
#
#                                         :  44%|████▍     | 41.5MB / 94.5MB
#
# Processing Files (0 / 1)                :  45%|████▌     | 42.6MB / 94.5MB, 1.78MB/s
# New Data Upload                         :  45%|████▌     | 42.6MB / 94.5MB, 1.78MB/s
#
#                                         :  45%|████▌     | 42.6MB / 94.5MB
#
# Processing Files (0 / 1)                :  46%|████▌     | 43.3MB / 94.5MB, 1.72MB/s
# New Data Upload                         :  46%|████▌     | 43.3MB / 94.5MB, 1.72MB/s
#
# Processing Files (0 / 1)                :  46%|████▋     | 43.8MB / 94.5MB, 1.78MB/s
# New Data Upload                         :  46%|████▋     | 43.8MB / 94.5MB, 1.78MB/s
#
#                                         :  46%|████▋     | 43.8MB / 94.5MB
#
#                                         :  46%|████▋     | 43.8MB / 94.5MB
#
# Processing Files (0 / 1)                :  48%|████▊     | 45.0MB / 94.5MB, 1.78MB/s
# New Data Upload                         :  48%|████▊     | 45.0MB / 94.5MB, 1.78MB/s
#
#                                         :  48%|████▊     | 45.0MB / 94.5MB
#
#                                         :  48%|████▊     | 45.0MB / 94.5MB
#
#                                         :  48%|████▊     | 45.0MB / 94.5MB
#
# Processing Files (0 / 1)                :  49%|████▉     | 46.2MB / 94.5MB, 1.78MB/s
# New Data Upload                         :  49%|████▉     | 46.2MB / 94.5MB, 1.78MB/s
#
#                                         :  49%|████▉     | 46.2MB / 94.5MB
#
# Processing Files (0 / 1)                :  50%|████▉     | 46.8MB / 94.5MB, 1.72MB/s
# New Data Upload                         :  50%|████▉     | 46.8MB / 94.5MB, 1.72MB/s
#
# Processing Files (0 / 1)                :  50%|█████     | 47.3MB / 94.5MB, 1.78MB/s
# New Data Upload                         :  50%|█████     | 47.3MB / 94.5MB, 1.78MB/s
#
#                                         :  50%|█████     | 47.3MB / 94.5MB
#
#                                         :  50%|█████     | 47.3MB / 94.5MB
#
# Processing Files (0 / 1)                :  51%|█████▏    | 48.5MB / 94.5MB, 1.78MB/s
# New Data Upload                         :  51%|█████▏    | 48.5MB / 94.5MB, 1.78MB/s
#
#                                         :  51%|█████▏    | 48.5MB / 94.5MB
#
#                                         :  51%|█████▏    | 48.5MB / 94.5MB
#
# Processing Files (0 / 1)                :  52%|█████▏    | 49.1MB / 94.5MB, 1.72MB/s
# New Data Upload                         :  52%|█████▏    | 49.1MB / 94.5MB, 1.72MB/s
#
# Processing Files (0 / 1)                :  53%|█████▎    | 49.7MB / 94.5MB, 1.78MB/s
# New Data Upload                         :  53%|█████▎    | 49.7MB / 94.5MB, 1.78MB/s
#
#                                         :  53%|█████▎    | 49.7MB / 94.5MB
#
# Processing Files (0 / 1)                :  53%|█████▎    | 50.2MB / 94.5MB, 1.72MB/s
# New Data Upload                         :  53%|█████▎    | 50.2MB / 94.5MB, 1.72MB/s
#
# Processing Files (0 / 1)                :  54%|█████▍    | 50.9MB / 94.5MB, 1.78MB/s
# New Data Upload                         :  54%|█████▍    | 50.9MB / 94.5MB, 1.78MB/s
#
#                                         :  54%|█████▍    | 50.9MB / 94.5MB
#
#                                         :  54%|█████▍    | 50.9MB / 94.5MB
#
# Processing Files (0 / 1)                :  54%|█████▍    | 51.4MB / 94.5MB, 1.72MB/s
# New Data Upload                         :  54%|█████▍    | 51.4MB / 94.5MB, 1.72MB/s
#
# Processing Files (0 / 1)                :  55%|█████▌    | 52.0MB / 94.5MB, 1.78MB/s
# New Data Upload                         :  55%|█████▌    | 52.0MB / 94.5MB, 1.78MB/s
#
#                                         :  55%|█████▌    | 52.0MB / 94.5MB
#
# Processing Files (0 / 1)                :  56%|█████▌    | 52.6MB / 94.5MB, 1.72MB/s
# New Data Upload                         :  56%|█████▌    | 52.6MB / 94.5MB, 1.72MB/s
#
#                                         :  56%|█████▌    | 52.6MB / 94.5MB
#
#                                         :  56%|█████▌    | 52.6MB / 94.5MB
#
# Processing Files (0 / 1)                :  56%|█████▌    | 53.1MB / 94.5MB, 1.65MB/s
# New Data Upload                         :  56%|█████▌    | 53.1MB / 94.5MB, 1.65MB/s
#
#                                         :  56%|█████▌    | 53.1MB / 94.5MB
#
#                                         :  56%|█████▌    | 53.1MB / 94.5MB
#
# Processing Files (0 / 1)                :  57%|█████▋    | 53.7MB / 94.5MB, 1.65MB/s
# New Data Upload                         :  57%|█████▋    | 53.7MB / 94.5MB, 1.65MB/s
#
#                                         :  57%|█████▋    | 53.7MB / 94.5MB
#
#                                         :  57%|█████▋    | 53.7MB / 94.5MB
#
#                                         :  57%|█████▋    | 53.7MB / 94.5MB
#
# Processing Files (0 / 1)                :  58%|█████▊    | 54.6MB / 94.5MB, 1.63MB/s
# New Data Upload                         :  58%|█████▊    | 54.6MB / 94.5MB, 1.63MB/s
#
#                                         :  58%|█████▊    | 54.6MB / 94.5MB
#
#                                         :  58%|█████▊    | 54.6MB / 94.5MB
#
# Processing Files (0 / 1)                :  58%|█████▊    | 55.2MB / 94.5MB, 1.57MB/s
# New Data Upload                         :  58%|█████▊    | 55.2MB / 94.5MB, 1.57MB/s
#
#                                         :  58%|█████▊    | 55.2MB / 94.5MB
#
#                                         :  58%|█████▊    | 55.2MB / 94.5MB
#
# Processing Files (0 / 1)                :  59%|█████▉    | 55.7MB / 94.5MB, 1.51MB/s
# New Data Upload                         :  59%|█████▉    | 55.7MB / 94.5MB, 1.51MB/s
#
#                                         :  59%|█████▉    | 55.7MB / 94.5MB
#
#                                         :  59%|█████▉    | 55.7MB / 94.5MB
#
# Processing Files (0 / 1)                :  60%|█████▉    | 56.3MB / 94.5MB, 1.45MB/s
# New Data Upload                         :  60%|█████▉    | 56.3MB / 94.5MB, 1.45MB/s
#
#                                         :  60%|█████▉    | 56.3MB / 94.5MB
#
#                                         :  60%|█████▉    | 56.3MB / 94.5MB
#
#                                         :  60%|█████▉    | 56.3MB / 94.5MB
#
# Processing Files (0 / 1)                :  60%|██████    | 56.8MB / 94.5MB, 1.39MB/s
# New Data Upload                         :  60%|██████    | 56.8MB / 94.5MB, 1.39MB/s
#
#                                         :  60%|██████    | 56.8MB / 94.5MB
#
#                                         :  60%|██████    | 56.8MB / 94.5MB
#
# Processing Files (0 / 1)                :  61%|██████    | 57.4MB / 94.5MB, 1.33MB/s
# New Data Upload                         :  61%|██████    | 57.4MB / 94.5MB, 1.33MB/s
#
#                                         :  61%|██████    | 57.4MB / 94.5MB
#
#                                         :  61%|██████    | 57.4MB / 94.5MB
#
# Processing Files (0 / 1)                :  61%|██████▏   | 57.9MB / 94.5MB, 1.27MB/s
# New Data Upload                         :  61%|██████▏   | 57.9MB / 94.5MB, 1.27MB/s
#
#                                         :  61%|██████▏   | 57.9MB / 94.5MB
#
#                                         :  61%|██████▏   | 57.9MB / 94.5MB
#
#                                         :  61%|██████▏   | 57.9MB / 94.5MB
#
# Processing Files (0 / 1)                :  62%|██████▏   | 58.4MB / 94.5MB, 1.20MB/s
# New Data Upload                         :  62%|██████▏   | 58.4MB / 94.5MB, 1.20MB/s
#
#                                         :  62%|██████▏   | 58.4MB / 94.5MB
#
#                                         :  62%|██████▏   | 58.4MB / 94.5MB
#
# Processing Files (0 / 1)                :  62%|██████▏   | 59.0MB / 94.5MB, 1.14MB/s
# New Data Upload                         :  62%|██████▏   | 59.0MB / 94.5MB, 1.14MB/s
#
#                                         :  62%|██████▏   | 59.0MB / 94.5MB
#
#                                         :  62%|██████▏   | 59.0MB / 94.5MB
#
# Processing Files (0 / 1)                :  63%|██████▎   | 59.5MB / 94.5MB, 1.08MB/s
# New Data Upload                         :  63%|██████▎   | 59.5MB / 94.5MB, 1.08MB/s
#
#                                         :  63%|██████▎   | 59.5MB / 94.5MB
#
#                                         :  63%|██████▎   | 59.5MB / 94.5MB
#
#                                         :  63%|██████▎   | 59.5MB / 94.5MB
#
# Processing Files (0 / 1)                :  64%|██████▎   | 60.1MB / 94.5MB, 1.02MB/s
# New Data Upload                         :  64%|██████▎   | 60.1MB / 94.5MB, 1.02MB/s
#
#                                         :  64%|██████▎   | 60.1MB / 94.5MB
#
#                                         :  64%|██████▎   | 60.1MB / 94.5MB
#
# Processing Files (0 / 1)                :  64%|██████▍   | 60.6MB / 94.5MB,  959kB/s
# New Data Upload                         :  64%|██████▍   | 60.6MB / 94.5MB,  959kB/s
#
#                                         :  64%|██████▍   | 60.6MB / 94.5MB
#
#                                         :  64%|██████▍   | 60.6MB / 94.5MB
#
# Processing Files (0 / 1)                :  65%|██████▍   | 61.2MB / 94.5MB,  897kB/s
# New Data Upload                         :  65%|██████▍   | 61.2MB / 94.5MB,  897kB/s
#
#                                         :  65%|██████▍   | 61.2MB / 94.5MB
#
#                                         :  65%|██████▍   | 61.2MB / 94.5MB
#
#                                         :  65%|██████▍   | 61.2MB / 94.5MB
#
# Processing Files (0 / 1)                :  65%|██████▌   | 61.7MB / 94.5MB,  897kB/s
# New Data Upload                         :  65%|██████▌   | 61.7MB / 94.5MB,  897kB/s
#
#                                         :  65%|██████▌   | 61.7MB / 94.5MB
#
#                                         :  65%|██████▌   | 61.7MB / 94.5MB
#
#                                         :  65%|██████▌   | 61.7MB / 94.5MB
#
# Processing Files (0 / 1)                :  66%|██████▌   | 62.3MB / 94.5MB,  844kB/s
# New Data Upload                         :  66%|██████▌   | 62.3MB / 94.5MB,  844kB/s
#
#                                         :  66%|██████▌   | 62.3MB / 94.5MB
#
#                                         :  66%|██████▌   | 62.3MB / 94.5MB
#
# Processing Files (0 / 1)                :  66%|██████▋   | 62.8MB / 94.5MB,  897kB/s
# New Data Upload                         :  66%|██████▋   | 62.8MB / 94.5MB,  897kB/s
#
#                                         :  66%|██████▋   | 62.8MB / 94.5MB
#
#                                         :  66%|██████▋   | 62.8MB / 94.5MB
#
# Processing Files (0 / 1)                :  67%|██████▋   | 63.4MB / 94.5MB,  855kB/s
# New Data Upload                         :  67%|██████▋   | 63.4MB / 94.5MB,  855kB/s
#
#                                         :  67%|██████▋   | 63.4MB / 94.5MB
#
#                                         :  67%|██████▋   | 63.4MB / 94.5MB
#
#                                         :  67%|██████▋   | 63.4MB / 94.5MB
#
# Processing Files (0 / 1)                :  68%|██████▊   | 63.9MB / 94.5MB,  801kB/s
# New Data Upload                         :  68%|██████▊   | 63.9MB / 94.5MB,  801kB/s
#
#                                         :  68%|██████▊   | 63.9MB / 94.5MB
#
#                                         :  68%|██████▊   | 63.9MB / 94.5MB
#
#                                         :  68%|██████▊   | 63.9MB / 94.5MB
#
# Processing Files (0 / 1)                :  68%|██████▊   | 64.4MB / 94.5MB,  802kB/s
# New Data Upload                         :  68%|██████▊   | 64.4MB / 94.5MB,  802kB/s
#
#                                         :  68%|██████▊   | 64.4MB / 94.5MB
#
#                                         :  68%|██████▊   | 64.4MB / 94.5MB
#
# Processing Files (0 / 1)                :  69%|██████▉   | 65.0MB / 94.5MB,  801kB/s
# New Data Upload                         :  69%|██████▉   | 65.0MB / 94.5MB,  801kB/s
#
#                                         :  69%|██████▉   | 65.0MB / 94.5MB
#
#                                         :  69%|██████▉   | 65.0MB / 94.5MB
#
# Processing Files (0 / 1)                :  69%|██████▉   | 65.5MB / 94.5MB,  801kB/s
# New Data Upload                         :  69%|██████▉   | 65.5MB / 94.5MB,  801kB/s
#
#                                         :  69%|██████▉   | 65.5MB / 94.5MB
#
#                                         :  69%|██████▉   | 65.5MB / 94.5MB
#
# Processing Files (0 / 1)                :  70%|██████▉   | 66.1MB / 94.5MB,  801kB/s
# New Data Upload                         :  70%|██████▉   | 66.1MB / 94.5MB,  801kB/s
#
#                                         :  70%|██████▉   | 66.1MB / 94.5MB
#
#                                         :  70%|██████▉   | 66.1MB / 94.5MB
#
#                                         :  70%|██████▉   | 66.1MB / 94.5MB
#
# Processing Files (0 / 1)                :  71%|███████   | 66.6MB / 94.5MB,  802kB/s
# New Data Upload                         :  71%|███████   | 66.6MB / 94.5MB,  802kB/s
#
#                                         :  71%|███████   | 66.6MB / 94.5MB
#
#                                         :  71%|███████   | 66.6MB / 94.5MB
#
# Processing Files (0 / 1)                :  71%|███████   | 67.2MB / 94.5MB,  802kB/s
# New Data Upload                         :  71%|███████   | 67.2MB / 94.5MB,  802kB/s
#
#                                         :  71%|███████   | 67.2MB / 94.5MB
#
#                                         :  71%|███████   | 67.2MB / 94.5MB
#
#                                         :  71%|███████   | 67.2MB / 94.5MB
#
# Processing Files (0 / 1)                :  72%|███████▏  | 67.7MB / 94.5MB,  802kB/s
# New Data Upload                         :  72%|███████▏  | 67.7MB / 94.5MB,  802kB/s
#
#                                         :  72%|███████▏  | 67.7MB / 94.5MB
#
#                                         :  72%|███████▏  | 67.7MB / 94.5MB
#
# Processing Files (0 / 1)                :  72%|███████▏  | 68.3MB / 94.5MB,  802kB/s
# New Data Upload                         :  72%|███████▏  | 68.3MB / 94.5MB,  802kB/s
#
#                                         :  72%|███████▏  | 68.3MB / 94.5MB
#
#                                         :  72%|███████▏  | 68.3MB / 94.5MB
#
# Processing Files (0 / 1)                :  73%|███████▎  | 68.8MB / 94.5MB,  802kB/s
# New Data Upload                         :  73%|███████▎  | 68.8MB / 94.5MB,  802kB/s
#
#                                         :  73%|███████▎  | 68.8MB / 94.5MB
#
#                                         :  73%|███████▎  | 68.8MB / 94.5MB
#
# Processing Files (0 / 1)                :  73%|███████▎  | 69.3MB / 94.5MB,  801kB/s
# New Data Upload                         :  73%|███████▎  | 69.3MB / 94.5MB,  801kB/s
#
#                                         :  73%|███████▎  | 69.3MB / 94.5MB
#
#                                         :  73%|███████▎  | 69.3MB / 94.5MB
#
#                                         :  73%|███████▎  | 69.3MB / 94.5MB
#
# Processing Files (0 / 1)                :  74%|███████▍  | 69.9MB / 94.5MB,  802kB/s
# New Data Upload                         :  74%|███████▍  | 69.9MB / 94.5MB,  802kB/s
#
#                                         :  74%|███████▍  | 69.9MB / 94.5MB
#
#                                         :  74%|███████▍  | 69.9MB / 94.5MB
#
# Processing Files (0 / 1)                :  75%|███████▍  | 70.4MB / 94.5MB,  855kB/s
# New Data Upload                         :  75%|███████▍  | 70.4MB / 94.5MB,  855kB/s
#
#                                         :  75%|███████▍  | 70.4MB / 94.5MB
#
#                                         :  75%|███████▍  | 70.4MB / 94.5MB
#
#                                         :  75%|███████▍  | 70.4MB / 94.5MB
#
#                                         :  75%|███████▍  | 70.4MB / 94.5MB
#
# Processing Files (0 / 1)                :  75%|███████▌  | 71.0MB / 94.5MB,  802kB/s
# New Data Upload                         :  75%|███████▌  | 71.0MB / 94.5MB,  802kB/s
#
#                                         :  75%|███████▌  | 71.0MB / 94.5MB
#
#                                         :  75%|███████▌  | 71.0MB / 94.5MB
#
# Processing Files (0 / 1)                :  76%|███████▌  | 71.5MB / 94.5MB,  801kB/s
# New Data Upload                         :  76%|███████▌  | 71.5MB / 94.5MB,  801kB/s
#
#                                         :  76%|███████▌  | 71.5MB / 94.5MB
#
#                                         :  76%|███████▌  | 71.5MB / 94.5MB
#
# Processing Files (0 / 1)                :  76%|███████▋  | 72.1MB / 94.5MB,  802kB/s
# New Data Upload                         :  76%|███████▋  | 72.1MB / 94.5MB,  802kB/s
#
#                                         :  76%|███████▋  | 72.1MB / 94.5MB
#
#                                         :  76%|███████▋  | 72.1MB / 94.5MB
#
#                                         :  76%|███████▋  | 72.1MB / 94.5MB
#
# Processing Files (0 / 1)                :  77%|███████▋  | 72.6MB / 94.5MB,  801kB/s
# New Data Upload                         :  77%|███████▋  | 72.6MB / 94.5MB,  801kB/s
#
#                                         :  77%|███████▋  | 72.6MB / 94.5MB
#
#                                         :  77%|███████▋  | 72.6MB / 94.5MB
#
# Processing Files (0 / 1)                :  77%|███████▋  | 73.2MB / 94.5MB,  801kB/s
# New Data Upload                         :  77%|███████▋  | 73.2MB / 94.5MB,  801kB/s
#
#                                         :  77%|███████▋  | 73.2MB / 94.5MB
#
#                                         :  77%|███████▋  | 73.2MB / 94.5MB
#
# Processing Files (0 / 1)                :  78%|███████▊  | 73.7MB / 94.5MB,  801kB/s
# New Data Upload                         :  78%|███████▊  | 73.7MB / 94.5MB,  801kB/s
#
#                                         :  78%|███████▊  | 73.7MB / 94.5MB
#
#                                         :  78%|███████▊  | 73.7MB / 94.5MB
#
# Processing Files (0 / 1)                :  79%|███████▊  | 74.3MB / 94.5MB,  802kB/s
# New Data Upload                         :  79%|███████▊  | 74.3MB / 94.5MB,  802kB/s
#
#                                         :  79%|███████▊  | 74.3MB / 94.5MB
#
#                                         :  79%|███████▊  | 74.3MB / 94.5MB
#
#                                         :  79%|███████▊  | 74.3MB / 94.5MB
#
# Processing Files (0 / 1)                :  79%|███████▉  | 74.8MB / 94.5MB,  801kB/s
# New Data Upload                         :  79%|███████▉  | 74.8MB / 94.5MB,  801kB/s
#
#                                         :  79%|███████▉  | 74.8MB / 94.5MB
#
#                                         :  79%|███████▉  | 74.8MB / 94.5MB
#
# Processing Files (0 / 1)                :  80%|███████▉  | 75.3MB / 94.5MB,  801kB/s
# New Data Upload                         :  80%|███████▉  | 75.3MB / 94.5MB,  801kB/s
#
#                                         :  80%|███████▉  | 75.3MB / 94.5MB
#
#                                         :  80%|███████▉  | 75.3MB / 94.5MB
#
# Processing Files (0 / 1)                :  80%|████████  | 75.9MB / 94.5MB,  855kB/s
# New Data Upload                         :  80%|████████  | 75.9MB / 94.5MB,  855kB/s
#
#                                         :  80%|████████  | 75.9MB / 94.5MB
#
#                                         :  80%|████████  | 75.9MB / 94.5MB
#
# Processing Files (0 / 1)                :  81%|████████  | 76.4MB / 94.5MB,  855kB/s
# New Data Upload                         :  81%|████████  | 76.4MB / 94.5MB,  855kB/s
#
#                                         :  81%|████████  | 76.4MB / 94.5MB
#
#                                         :  81%|████████  | 76.4MB / 94.5MB
#
# Processing Files (0 / 1)                :  81%|████████▏ | 77.0MB / 94.5MB,  855kB/s
# New Data Upload                         :  81%|████████▏ | 77.0MB / 94.5MB,  855kB/s
#
#                                         :  81%|████████▏ | 77.0MB / 94.5MB
#
#                                         :  81%|████████▏ | 77.0MB / 94.5MB
#
#                                         :  81%|████████▏ | 77.0MB / 94.5MB
#
# Processing Files (0 / 1)                :  82%|████████▏ | 77.5MB / 94.5MB,  801kB/s
# New Data Upload                         :  82%|████████▏ | 77.5MB / 94.5MB,  801kB/s
#
#                                         :  82%|████████▏ | 77.5MB / 94.5MB
#
#                                         :  82%|████████▏ | 77.5MB / 94.5MB
#
# Processing Files (0 / 1)                :  83%|████████▎ | 78.1MB / 94.5MB,  855kB/s
# New Data Upload                         :  83%|████████▎ | 78.1MB / 94.5MB,  855kB/s
#
#                                         :  83%|████████▎ | 78.1MB / 94.5MB
#
#                                         :  83%|████████▎ | 78.1MB / 94.5MB
#
# Processing Files (0 / 1)                :  83%|████████▎ | 78.6MB / 94.5MB,  855kB/s
# New Data Upload                         :  83%|████████▎ | 78.6MB / 94.5MB,  855kB/s
#
#                                         :  83%|████████▎ | 78.6MB / 94.5MB
#
#                                         :  83%|████████▎ | 78.6MB / 94.5MB
#
# Processing Files (0 / 1)                :  84%|████████▍ | 79.2MB / 94.5MB,  855kB/s
# New Data Upload                         :  84%|████████▍ | 79.2MB / 94.5MB,  855kB/s
#
#                                         :  84%|████████▍ | 79.2MB / 94.5MB
#
#                                         :  84%|████████▍ | 79.2MB / 94.5MB
#
#                                         :  84%|████████▍ | 79.2MB / 94.5MB
#
# Processing Files (0 / 1)                :  84%|████████▍ | 79.7MB / 94.5MB,  855kB/s
# New Data Upload                         :  84%|████████▍ | 79.7MB / 94.5MB,  855kB/s
#
#                                         :  84%|████████▍ | 79.7MB / 94.5MB
#
#                                         :  84%|████████▍ | 79.7MB / 94.5MB
#
# Processing Files (0 / 1)                :  85%|████████▍ | 80.2MB / 94.5MB,  855kB/s
# New Data Upload                         :  85%|████████▍ | 80.2MB / 94.5MB,  855kB/s
#
#                                         :  85%|████████▍ | 80.2MB / 94.5MB
#
#                                         :  85%|████████▍ | 80.2MB / 94.5MB
#
# Processing Files (0 / 1)                :  86%|████████▌ | 80.8MB / 94.5MB,  855kB/s
# New Data Upload                         :  86%|████████▌ | 80.8MB / 94.5MB,  855kB/s
#
#                                         :  86%|████████▌ | 80.8MB / 94.5MB
#
#                                         :  86%|████████▌ | 80.8MB / 94.5MB
#
#                                         :  86%|████████▌ | 80.8MB / 94.5MB
#
# Processing Files (0 / 1)                :  86%|████████▌ | 81.3MB / 94.5MB,  855kB/s
# New Data Upload                         :  86%|████████▌ | 81.3MB / 94.5MB,  855kB/s
#
#                                         :  86%|████████▌ | 81.3MB / 94.5MB
#
#                                         :  86%|████████▌ | 81.3MB / 94.5MB
#
# Processing Files (0 / 1)                :  87%|████████▋ | 81.9MB / 94.5MB,  855kB/s
# New Data Upload                         :  87%|████████▋ | 81.9MB / 94.5MB,  855kB/s
#
#                                         :  87%|████████▋ | 81.9MB / 94.5MB
#
#                                         :  87%|████████▋ | 81.9MB / 94.5MB
#
# Processing Files (0 / 1)                :  87%|████████▋ | 82.4MB / 94.5MB,  855kB/s
# New Data Upload                         :  87%|████████▋ | 82.4MB / 94.5MB,  855kB/s
#
#                                         :  87%|████████▋ | 82.4MB / 94.5MB
#
#                                         :  87%|████████▋ | 82.4MB / 94.5MB
#
# Processing Files (0 / 1)                :  88%|████████▊ | 83.0MB / 94.5MB,  855kB/s
# New Data Upload                         :  88%|████████▊ | 83.0MB / 94.5MB,  855kB/s
#
#                                         :  88%|████████▊ | 83.0MB / 94.5MB
#
#                                         :  88%|████████▊ | 83.0MB / 94.5MB
#
#                                         :  88%|████████▊ | 83.0MB / 94.5MB
#
# Processing Files (0 / 1)                :  88%|████████▊ | 83.5MB / 94.5MB,  855kB/s
# New Data Upload                         :  88%|████████▊ | 83.5MB / 94.5MB,  855kB/s
#
#                                         :  88%|████████▊ | 83.5MB / 94.5MB
#
#                                         :  88%|████████▊ | 83.5MB / 94.5MB
#
# Processing Files (0 / 1)                :  89%|████████▉ | 84.1MB / 94.5MB,  855kB/s
# New Data Upload                         :  89%|████████▉ | 84.1MB / 94.5MB,  855kB/s
#
#                                         :  89%|████████▉ | 84.1MB / 94.5MB
#
#                                         :  89%|████████▉ | 84.1MB / 94.5MB
#
# Processing Files (0 / 1)                :  90%|████████▉ | 84.6MB / 94.5MB,  855kB/s
# New Data Upload                         :  90%|████████▉ | 84.6MB / 94.5MB,  855kB/s
#
#                                         :  90%|████████▉ | 84.6MB / 94.5MB
#
#                                         :  90%|████████▉ | 84.6MB / 94.5MB
#
# Processing Files (0 / 1)                :  90%|█████████ | 85.2MB / 94.5MB,  855kB/s
# New Data Upload                         :  90%|█████████ | 85.2MB / 94.5MB,  855kB/s
#
#                                         :  90%|█████████ | 85.2MB / 94.5MB
#
#                                         :  90%|█████████ | 85.2MB / 94.5MB
#
# Processing Files (0 / 1)                :  91%|█████████ | 85.7MB / 94.5MB,  855kB/s
# New Data Upload                         :  91%|█████████ | 85.7MB / 94.5MB,  855kB/s
#
#                                         :  91%|█████████ | 85.7MB / 94.5MB
#
#                                         :  91%|█████████ | 85.7MB / 94.5MB
#
# Processing Files (0 / 1)                :  91%|█████████▏| 86.2MB / 94.5MB,  855kB/s
# New Data Upload                         :  91%|█████████▏| 86.2MB / 94.5MB,  855kB/s
#
#                                         :  91%|█████████▏| 86.2MB / 94.5MB
#
#                                         :  91%|█████████▏| 86.2MB / 94.5MB
#
#                                         :  91%|█████████▏| 86.2MB / 94.5MB
#
# Processing Files (0 / 1)                :  92%|█████████▏| 86.8MB / 94.5MB,  855kB/s
# New Data Upload                         :  92%|█████████▏| 86.8MB / 94.5MB,  855kB/s
#
#                                         :  92%|█████████▏| 86.8MB / 94.5MB
#
#                                         :  92%|█████████▏| 86.8MB / 94.5MB
#
# Processing Files (0 / 1)                :  92%|█████████▏| 87.3MB / 94.5MB,  855kB/s
# New Data Upload                         :  92%|█████████▏| 87.3MB / 94.5MB,  855kB/s
#
#                                         :  92%|█████████▏| 87.3MB / 94.5MB
#
# ...
#
#                                         :  64%|██████▍   | 58.1MB / 90.6MB
#
#                                         :  64%|██████▍   | 58.1MB / 90.6MB
#
#                                         :  64%|██████▍   | 58.1MB / 90.6MB
#
# Processing Files (0 / 1)                :  65%|██████▍   | 58.7MB / 90.6MB,  796kB/s
# New Data Upload                         :  65%|██████▍   | 58.7MB / 90.6MB,  796kB/s
#
#                                         :  65%|██████▍   | 58.7MB / 90.6MB
#
#                                         :  65%|██████▍   | 58.7MB / 90.6MB
#
# Processing Files (0 / 1)                :  65%|██████▌   | 59.2MB / 90.6MB,  796kB/s
# New Data Upload                         :  65%|██████▌   | 59.2MB / 90.6MB,  796kB/s
#
#                                         :  65%|██████▌   | 59.2MB / 90.6MB
#
#                                         :  65%|██████▌   | 59.2MB / 90.6MB
#
#                                         :  65%|██████▌   | 59.2MB / 90.6MB
#
# Processing Files (0 / 1)                :  66%|██████▌   | 59.7MB / 90.6MB,  796kB/s
# New Data Upload                         :  66%|██████▌   | 59.7MB / 90.6MB,  796kB/s
#
#                                         :  66%|██████▌   | 59.7MB / 90.6MB
#
#                                         :  66%|██████▌   | 59.7MB / 90.6MB
#
# Processing Files (0 / 1)                :  67%|██████▋   | 60.3MB / 90.6MB,  796kB/s
# New Data Upload                         :  67%|██████▋   | 60.3MB / 90.6MB,  796kB/s
#
#                                         :  67%|██████▋   | 60.3MB / 90.6MB
#
#                                         :  67%|██████▋   | 60.3MB / 90.6MB
#
# Processing Files (0 / 1)                :  67%|██████▋   | 60.8MB / 90.6MB,  796kB/s
# New Data Upload                         :  67%|██████▋   | 60.8MB / 90.6MB,  796kB/s
#
#                                         :  67%|██████▋   | 60.8MB / 90.6MB
#
#                                         :  67%|██████▋   | 60.8MB / 90.6MB
#
#                                         :  67%|██████▋   | 60.8MB / 90.6MB
#
# Processing Files (0 / 1)                :  68%|██████▊   | 61.4MB / 90.6MB,  796kB/s
# New Data Upload                         :  68%|██████▊   | 61.4MB / 90.6MB,  796kB/s
#
#                                         :  68%|██████▊   | 61.4MB / 90.6MB
#
#                                         :  68%|██████▊   | 61.4MB / 90.6MB
#
#                                         :  68%|██████▊   | 61.4MB / 90.6MB
#
# Processing Files (0 / 1)                :  68%|██████▊   | 61.9MB / 90.6MB,  796kB/s
# New Data Upload                         :  68%|██████▊   | 61.9MB / 90.6MB,  796kB/s
#
#                                         :  68%|██████▊   | 61.9MB / 90.6MB
#
#                                         :  68%|██████▊   | 61.9MB / 90.6MB
#
# Processing Files (0 / 1)                :  69%|██████▉   | 62.5MB / 90.6MB,  796kB/s
# New Data Upload                         :  69%|██████▉   | 62.5MB / 90.6MB,  796kB/s
#
#                                         :  69%|██████▉   | 62.5MB / 90.6MB
#
#                                         :  69%|██████▉   | 62.5MB / 90.6MB
#
# Processing Files (0 / 1)                :  70%|██████▉   | 63.0MB / 90.6MB,  796kB/s
# New Data Upload                         :  70%|██████▉   | 63.0MB / 90.6MB,  796kB/s
#
#                                         :  70%|██████▉   | 63.0MB / 90.6MB
#
#                                         :  70%|██████▉   | 63.0MB / 90.6MB
#
#                                         :  70%|██████▉   | 63.0MB / 90.6MB
#
# Processing Files (0 / 1)                :  70%|███████   | 63.5MB / 90.6MB,  796kB/s
# New Data Upload                         :  70%|███████   | 63.5MB / 90.6MB,  796kB/s
#
#                                         :  70%|███████   | 63.5MB / 90.6MB
#
#                                         :  70%|███████   | 63.5MB / 90.6MB
#
#                                         :  70%|███████   | 63.5MB / 90.6MB
#
# Processing Files (0 / 1)                :  71%|███████   | 64.1MB / 90.6MB,  796kB/s
# New Data Upload                         :  71%|███████   | 64.1MB / 90.6MB,  796kB/s
#
#                                         :  71%|███████   | 64.1MB / 90.6MB
#
#                                         :  71%|███████   | 64.1MB / 90.6MB
#
# Processing Files (0 / 1)                :  71%|███████▏  | 64.6MB / 90.6MB,  796kB/s
# New Data Upload                         :  71%|███████▏  | 64.6MB / 90.6MB,  796kB/s
#
#                                         :  71%|███████▏  | 64.6MB / 90.6MB
#
#                                         :  71%|███████▏  | 64.6MB / 90.6MB
#
#                                         :  71%|███████▏  | 64.6MB / 90.6MB
#
# Processing Files (0 / 1)                :  72%|███████▏  | 65.2MB / 90.6MB,  796kB/s
# New Data Upload                         :  72%|███████▏  | 65.2MB / 90.6MB,  796kB/s
#
#                                         :  72%|███████▏  | 65.2MB / 90.6MB
#
#                                         :  72%|███████▏  | 65.2MB / 90.6MB
#
#                                         :  72%|███████▏  | 65.2MB / 90.6MB
#
# Processing Files (0 / 1)                :  73%|███████▎  | 65.7MB / 90.6MB,  796kB/s
# New Data Upload                         :  73%|███████▎  | 65.7MB / 90.6MB,  796kB/s
#
#                                         :  73%|███████▎  | 65.7MB / 90.6MB
#
#                                         :  73%|███████▎  | 65.7MB / 90.6MB
#
# Processing Files (0 / 1)                :  73%|███████▎  | 66.2MB / 90.6MB,  796kB/s
# New Data Upload                         :  73%|███████▎  | 66.2MB / 90.6MB,  796kB/s
#
#                                         :  73%|███████▎  | 66.2MB / 90.6MB
#
#                                         :  73%|███████▎  | 66.2MB / 90.6MB
#
#                                         :  73%|███████▎  | 66.2MB / 90.6MB
#
# Processing Files (0 / 1)                :  74%|███████▍  | 66.8MB / 90.6MB,  796kB/s
# New Data Upload                         :  74%|███████▍  | 66.8MB / 90.6MB,  796kB/s
#
#                                         :  74%|███████▍  | 66.8MB / 90.6MB
#
#                                         :  74%|███████▍  | 66.8MB / 90.6MB
#
# Processing Files (0 / 1)                :  74%|███████▍  | 67.3MB / 90.6MB,  796kB/s
# New Data Upload                         :  74%|███████▍  | 67.3MB / 90.6MB,  796kB/s
#
#                                         :  74%|███████▍  | 67.3MB / 90.6MB
#
#                                         :  74%|███████▍  | 67.3MB / 90.6MB
#
#                                         :  74%|███████▍  | 67.3MB / 90.6MB
#
# Processing Files (0 / 1)                :  75%|███████▍  | 67.9MB / 90.6MB,  796kB/s
# New Data Upload                         :  75%|███████▍  | 67.9MB / 90.6MB,  796kB/s
#
#                                         :  75%|███████▍  | 67.9MB / 90.6MB
#
#                                         :  75%|███████▍  | 67.9MB / 90.6MB
#
# Processing Files (0 / 1)                :  76%|███████▌  | 68.4MB / 90.6MB,  796kB/s
# New Data Upload                         :  76%|███████▌  | 68.4MB / 90.6MB,  796kB/s
#
#                                         :  76%|███████▌  | 68.4MB / 90.6MB
#
#                                         :  76%|███████▌  | 68.4MB / 90.6MB
#
#                                         :  76%|███████▌  | 68.4MB / 90.6MB
#
# Processing Files (0 / 1)                :  76%|███████▌  | 69.0MB / 90.6MB,  796kB/s
# New Data Upload                         :  76%|███████▌  | 69.0MB / 90.6MB,  796kB/s
#
#                                         :  76%|███████▌  | 69.0MB / 90.6MB
#
#                                         :  76%|███████▌  | 69.0MB / 90.6MB
#
# Processing Files (0 / 1)                :  77%|███████▋  | 69.5MB / 90.6MB,  796kB/s
# New Data Upload                         :  77%|███████▋  | 69.5MB / 90.6MB,  796kB/s
#
#                                         :  77%|███████▋  | 69.5MB / 90.6MB
#
#                                         :  77%|███████▋  | 69.5MB / 90.6MB
#
#                                         :  77%|███████▋  | 69.5MB / 90.6MB
#
# Processing Files (0 / 1)                :  77%|███████▋  | 70.0MB / 90.6MB,  796kB/s
# New Data Upload                         :  77%|███████▋  | 70.0MB / 90.6MB,  796kB/s
#
#                                         :  77%|███████▋  | 70.0MB / 90.6MB
#
#                                         :  77%|███████▋  | 70.0MB / 90.6MB
#
#                                         :  77%|███████▋  | 70.0MB / 90.6MB
#
# Processing Files (0 / 1)                :  78%|███████▊  | 70.6MB / 90.6MB,  743kB/s
# New Data Upload                         :  78%|███████▊  | 70.6MB / 90.6MB,  743kB/s
#
#                                         :  78%|███████▊  | 70.6MB / 90.6MB
#
#                                         :  78%|███████▊  | 70.6MB / 90.6MB
#
# Processing Files (0 / 1)                :  79%|███████▊  | 71.1MB / 90.6MB,  796kB/s
# New Data Upload                         :  79%|███████▊  | 71.1MB / 90.6MB,  796kB/s
#
#                                         :  79%|███████▊  | 71.1MB / 90.6MB
#
#                                         :  79%|███████▊  | 71.1MB / 90.6MB
#
#                                         :  79%|███████▊  | 71.1MB / 90.6MB
#
# Processing Files (0 / 1)                :  79%|███████▉  | 71.7MB / 90.6MB,  796kB/s
# New Data Upload                         :  79%|███████▉  | 71.7MB / 90.6MB,  796kB/s
#
#                                         :  79%|███████▉  | 71.7MB / 90.6MB
#
#                                         :  79%|███████▉  | 71.7MB / 90.6MB
#
# Processing Files (0 / 1)                :  80%|███████▉  | 72.2MB / 90.6MB,  796kB/s
# New Data Upload                         :  80%|███████▉  | 72.2MB / 90.6MB,  796kB/s
#
#                                         :  80%|███████▉  | 72.2MB / 90.6MB
#
#                                         :  80%|███████▉  | 72.2MB / 90.6MB
#
#                                         :  80%|███████▉  | 72.2MB / 90.6MB
#
# Processing Files (0 / 1)                :  80%|████████  | 72.7MB / 90.6MB,  796kB/s
# New Data Upload                         :  80%|████████  | 72.7MB / 90.6MB,  796kB/s
#
#                                         :  80%|████████  | 72.7MB / 90.6MB
#
#                                         :  80%|████████  | 72.7MB / 90.6MB
#
# Processing Files (0 / 1)                :  81%|████████  | 73.3MB / 90.6MB,  796kB/s
# New Data Upload                         :  81%|████████  | 73.3MB / 90.6MB,  796kB/s
#
#                                         :  81%|████████  | 73.3MB / 90.6MB
#
#                                         :  81%|████████  | 73.3MB / 90.6MB
#
#                                         :  81%|████████  | 73.3MB / 90.6MB
#
# Processing Files (0 / 1)                :  82%|████████▏ | 73.8MB / 90.6MB,  796kB/s
# New Data Upload                         :  82%|████████▏ | 73.8MB / 90.6MB,  796kB/s
#
#                                         :  82%|████████▏ | 73.8MB / 90.6MB
#
#                                         :  82%|████████▏ | 73.8MB / 90.6MB
#
# Processing Files (0 / 1)                :  82%|████████▏ | 74.4MB / 90.6MB,  796kB/s
# New Data Upload                         :  82%|████████▏ | 74.4MB / 90.6MB,  796kB/s
#
#                                         :  82%|████████▏ | 74.4MB / 90.6MB
#
#                                         :  82%|████████▏ | 74.4MB / 90.6MB
#
#                                         :  82%|████████▏ | 74.4MB / 90.6MB
#
# Processing Files (0 / 1)                :  83%|████████▎ | 74.9MB / 90.6MB,  796kB/s
# New Data Upload                         :  83%|████████▎ | 74.9MB / 90.6MB,  796kB/s
#
#                                         :  83%|████████▎ | 74.9MB / 90.6MB
#
#                                         :  83%|████████▎ | 74.9MB / 90.6MB
#
# Processing Files (0 / 1)                :  83%|████████▎ | 75.5MB / 90.6MB,  796kB/s
# New Data Upload                         :  83%|████████▎ | 75.5MB / 90.6MB,  796kB/s
#
#                                         :  83%|████████▎ | 75.5MB / 90.6MB
#
#                                         :  83%|████████▎ | 75.5MB / 90.6MB
#
#                                         :  83%|████████▎ | 75.5MB / 90.6MB
#
# Processing Files (0 / 1)                :  84%|████████▍ | 76.0MB / 90.6MB,  796kB/s
# New Data Upload                         :  84%|████████▍ | 76.0MB / 90.6MB,  796kB/s
#
#                                         :  84%|████████▍ | 76.0MB / 90.6MB
#
#                                         :  84%|████████▍ | 76.0MB / 90.6MB
#
# Processing Files (0 / 1)                :  85%|████████▍ | 76.5MB / 90.6MB,  796kB/s
# New Data Upload                         :  85%|████████▍ | 76.5MB / 90.6MB,  796kB/s
#
#                                         :  85%|████████▍ | 76.5MB / 90.6MB
#
#                                         :  85%|████████▍ | 76.5MB / 90.6MB
#
#                                         :  85%|████████▍ | 76.5MB / 90.6MB
#
# Processing Files (0 / 1)                :  85%|████████▌ | 77.1MB / 90.6MB,  796kB/s
# New Data Upload                         :  85%|████████▌ | 77.1MB / 90.6MB,  796kB/s
#
#                                         :  85%|████████▌ | 77.1MB / 90.6MB
#
#                                         :  85%|████████▌ | 77.1MB / 90.6MB
#
# Processing Files (0 / 1)                :  86%|████████▌ | 77.6MB / 90.6MB,  796kB/s
# New Data Upload                         :  86%|████████▌ | 77.6MB / 90.6MB,  796kB/s
#
#                                         :  86%|████████▌ | 77.6MB / 90.6MB
#
#                                         :  86%|████████▌ | 77.6MB / 90.6MB
#
#                                         :  86%|████████▌ | 77.6MB / 90.6MB
#
# Processing Files (0 / 1)                :  86%|████████▋ | 78.2MB / 90.6MB,  796kB/s
# New Data Upload                         :  86%|████████▋ | 78.2MB / 90.6MB,  796kB/s
#
#                                         :  86%|████████▋ | 78.2MB / 90.6MB
#
#                                         :  86%|████████▋ | 78.2MB / 90.6MB
#
# Processing Files (0 / 1)                :  87%|████████▋ | 78.7MB / 90.6MB,  796kB/s
# New Data Upload                         :  87%|████████▋ | 78.7MB / 90.6MB,  796kB/s
#
#                                         :  87%|████████▋ | 78.7MB / 90.6MB
#
#                                         :  87%|████████▋ | 78.7MB / 90.6MB
#
#                                         :  87%|████████▋ | 78.7MB / 90.6MB
#
# Processing Files (0 / 1)                :  88%|████████▊ | 79.2MB / 90.6MB,  796kB/s
# New Data Upload                         :  88%|████████▊ | 79.2MB / 90.6MB,  796kB/s
#
#                                         :  88%|████████▊ | 79.2MB / 90.6MB
#
#                                         :  88%|████████▊ | 79.2MB / 90.6MB
#
# Processing Files (0 / 1)                :  88%|████████▊ | 79.8MB / 90.6MB,  796kB/s
# New Data Upload                         :  88%|████████▊ | 79.8MB / 90.6MB,  796kB/s
#
#                                         :  88%|████████▊ | 79.8MB / 90.6MB

# %%
# Out:
# Processing Files (0 / 0)                : |          |  0.00B /  0.00B
# New Data Upload                         : |          |  0.00B /  0.00B
#
#   /home/jovyan/work/data/train.csv      :   0%|          | 16.7MB / 6.31GB
#
# Processing Files (0 / 1)                :   0%|          | 16.7MB / 6.31GB, 4.17MB/s
#
# Processing Files (0 / 1)                :   1%|          | 50.3MB / 6.31GB, 12.0MB/s
#
# Processing Files (0 / 1)                :   1%|▏         | 92.2MB / 6.31GB, 21.0MB/s
#
# Processing Files (0 / 1)                :   2%|▏         |  126MB / 6.31GB, 27.4MB/s
#
# Processing Files (0 / 1)                :   3%|▎         |  168MB / 6.31GB, 34.9MB/s
#
# Processing Files (0 / 1)                :   3%|▎         |  210MB / 6.31GB, 41.9MB/s
#
# Processing Files (0 / 1)                :   4%|▍         |  243MB / 6.31GB, 46.8MB/s
#
# Processing Files (0 / 1)                :   5%|▍         |  285MB / 6.31GB, 52.8MB/s
#
# Processing Files (0 / 1)                :   5%|▌         |  327MB / 6.31GB, 58.4MB/s
#
# Processing Files (0 / 1)                :   6%|▌         |  361MB / 6.31GB, 62.2MB/s
#
# Processing Files (0 / 1)                :   6%|▋         |  394MB / 6.31GB, 65.7MB/s
#
# Processing Files (0 / 1)                :   7%|▋         |  428MB / 6.31GB, 69.0MB/s
#
# Processing Files (0 / 1)                :   7%|▋         |  461MB / 6.31GB, 72.1MB/s
#
# Processing Files (0 / 1)                :   8%|▊         |  486MB / 6.31GB, 73.7MB/s
#
# Processing Files (0 / 1)                :   8%|▊         |  512MB / 6.31GB, 75.2MB/s
#
# Processing Files (0 / 1)                :   9%|▊         |  537MB / 6.31GB, 76.7MB/s
#
# Processing Files (0 / 1)                :   9%|▉         |  562MB / 6.31GB, 78.1MB/s
#
# Processing Files (0 / 1)                :   9%|▉         |  587MB / 6.31GB, 79.4MB/s
#
# Processing Files (0 / 1)                :  10%|▉         |  612MB / 6.31GB, 80.6MB/s
#
# Processing Files (0 / 1)                :  10%|█         |  646MB / 6.31GB, 82.8MB/s
#
# Processing Files (0 / 1)                :  11%|█         |  671MB / 6.31GB, 83.9MB/s
#
# Processing Files (0 / 1)                :  11%|█         |  705MB / 6.31GB, 85.9MB/s
#
# Processing Files (0 / 1)                :  12%|█▏        |  730MB / 6.31GB, 86.9MB/s
#
# Processing Files (0 / 1)                :  12%|█▏        |  755MB / 6.31GB, 87.8MB/s
#
# Processing Files (0 / 1)                :  13%|█▎        |  788MB / 6.31GB, 89.6MB/s
#
# Processing Files (0 / 1)                :  13%|█▎        |  814MB / 6.31GB, 90.4MB/s
#
# Processing Files (0 / 1)                :  13%|█▎        |  839MB / 6.31GB, 91.2MB/s
#
# Processing Files (0 / 1)                :  14%|█▎        |  864MB / 6.31GB, 91.9MB/s
#
# Processing Files (0 / 1)                :  14%|█▍        |  898MB / 6.31GB, 93.5MB/s
#
# Processing Files (0 / 1)                :  15%|█▍        |  923MB / 6.31GB, 94.2MB/s
#
# Processing Files (0 / 1)                :  15%|█▌        |  956MB / 6.31GB, 95.6MB/s
#
# Processing Files (0 / 1)                :  16%|█▌        |  981MB / 6.31GB, 96.2MB/s
#
# Processing Files (0 / 1)                :  16%|█▌        | 1.01GB / 6.31GB, 99.5MB/s
#
# Processing Files (0 / 1)                :  16%|█▋        | 1.04GB / 6.31GB,  102MB/s
#
# Processing Files (0 / 1)                :  17%|█▋        | 1.07GB / 6.31GB,  105MB/s
#
# Processing Files (0 / 1)                :  17%|█▋        | 1.10GB / 6.31GB,  108MB/s
#
# Processing Files (0 / 1)                :  18%|█▊        | 1.13GB / 6.31GB,  111MB/s
#
# Processing Files (0 / 1)                :  18%|█▊        | 1.16GB / 6.31GB,  114MB/s
#
# Processing Files (0 / 1)                :  19%|█▉        | 1.19GB / 6.31GB,  117MB/s
#
# Processing Files (0 / 1)                :  19%|█▉        | 1.22GB / 6.31GB,  119MB/s
#
# Processing Files (0 / 1)                :  20%|█▉        | 1.25GB / 6.31GB,  123MB/s
#
# Processing Files (0 / 1)                :  20%|██        | 1.27GB / 6.31GB,  125MB/s
#
# Processing Files (0 / 1)                :  21%|██        | 1.31GB / 6.31GB,  128MB/s
#
# Processing Files (0 / 1)                :  21%|██        | 1.33GB / 6.31GB,  131MB/s
#
# Processing Files (0 / 1)                :  22%|██▏       | 1.37GB / 6.31GB,  134MB/s
#
# Processing Files (0 / 1)                :  22%|██▏       | 1.39GB / 6.31GB,  137MB/s
#
# Processing Files (0 / 1)                :  22%|██▏       | 1.42GB / 6.31GB,  139MB/s
#
# Processing Files (0 / 1)                :  23%|██▎       | 1.45GB / 6.31GB,  142MB/s
#
# Processing Files (0 / 1)                :  23%|██▎       | 1.48GB / 6.31GB,  145MB/s
#
# Processing Files (0 / 1)                :  24%|██▍       | 1.51GB / 6.31GB,  148MB/s
#
# Processing Files (0 / 1)                :  24%|██▍       | 1.54GB / 6.31GB,  151MB/s
#
# Processing Files (0 / 1)                :  25%|██▍       | 1.57GB / 6.31GB,  152MB/s
#
# Processing Files (0 / 1)                :  25%|██▌       | 1.59GB / 6.31GB,  151MB/s
#
# Processing Files (0 / 1)                :  26%|██▌       | 1.62GB / 6.31GB,  150MB/s
#
# Processing Files (0 / 1)                :  26%|██▌       | 1.64GB / 6.31GB,  149MB/s
#
# Processing Files (0 / 1)                :  27%|██▋       | 1.68GB / 6.31GB,  148MB/s
#
# Processing Files (0 / 1)                :  27%|██▋       | 1.71GB / 6.31GB,  147MB/s
#
# Processing Files (0 / 1)                :  28%|██▊       | 1.74GB / 6.31GB,  146MB/s
#
# Processing Files (0 / 1)                :  28%|██▊       | 1.76GB / 6.31GB,  145MB/s
#
# Processing Files (0 / 1)                :  28%|██▊       | 1.80GB / 6.31GB,  144MB/s
#
# Processing Files (0 / 1)                :  29%|██▉       | 1.82GB / 6.31GB,  143MB/s
#
# Processing Files (0 / 1)                :  29%|██▉       | 1.85GB / 6.31GB,  143MB/s
#
# Processing Files (0 / 1)                :  30%|██▉       | 1.88GB / 6.31GB,  142MB/s
#
# Processing Files (0 / 1)                :  30%|███       | 1.91GB / 6.31GB,  142MB/s
#
# Processing Files (0 / 1)                :  31%|███       | 1.94GB / 6.31GB,  142MB/s
#
# Processing Files (0 / 1)                :  31%|███       | 1.96GB / 6.31GB,  142MB/s
#
# Processing Files (0 / 1)                :  32%|███▏      | 1.99GB / 6.31GB,  142MB/s
#
# Processing Files (0 / 1)                :  32%|███▏      | 2.02GB / 6.31GB,  143MB/s
#
# Processing Files (0 / 1)                :  32%|███▏      | 2.05GB / 6.31GB,  143MB/s
#
# Processing Files (0 / 1)                :  33%|███▎      | 2.08GB / 6.31GB,  144MB/s
#
# Processing Files (0 / 1)                :  33%|███▎      | 2.11GB / 6.31GB,  143MB/s
#
# Processing Files (0 / 1)                :  34%|███▍      | 2.13GB / 6.31GB,  143MB/s
#
# Processing Files (0 / 1)                :  34%|███▍      | 2.16GB / 6.31GB,  143MB/s
#
# Processing Files (0 / 1)                :  35%|███▍      | 2.20GB / 6.31GB,  144MB/s
#
# Processing Files (0 / 1)                :  35%|███▌      | 2.22GB / 6.31GB,  144MB/s
#
# Processing Files (0 / 1)                :  36%|███▌      | 2.26GB / 6.31GB,  144MB/s
#
# Processing Files (0 / 1)                :  36%|███▌      | 2.28GB / 6.31GB,  144MB/s
#
# Processing Files (0 / 1)                :  37%|███▋      | 2.31GB / 6.31GB,  144MB/s
#
# Processing Files (0 / 1)                :  37%|███▋      | 2.33GB / 6.31GB,  144MB/s
#
# Processing Files (0 / 1)                :  37%|███▋      | 2.36GB / 6.31GB,  143MB/s
#
# Processing Files (0 / 1)                :  38%|███▊      | 2.38GB / 6.31GB,  143MB/s
#
# Processing Files (0 / 1)                :  38%|███▊      | 2.41GB / 6.31GB,  142MB/s
#
# Processing Files (0 / 1)                :  39%|███▊      | 2.44GB / 6.31GB,  143MB/s
#
# Processing Files (0 / 1)                :  39%|███▉      | 2.47GB / 6.31GB,  143MB/s
#
# Processing Files (0 / 1)                :  40%|███▉      | 2.50GB / 6.31GB,  143MB/s
#
# Processing Files (0 / 1)                :  40%|████      | 2.53GB / 6.31GB,  143MB/s
#
# Processing Files (0 / 1)                :  41%|████      | 2.56GB / 6.31GB,  143MB/s
#
# Processing Files (0 / 1)                :  41%|████      | 2.59GB / 6.31GB,  143MB/s
#
# Processing Files (0 / 1)                :  42%|████▏     | 2.62GB / 6.31GB,  143MB/s
#
# Processing Files (0 / 1)                :  42%|████▏     | 2.65GB / 6.31GB,  143MB/s
#
# Processing Files (0 / 1)                :  42%|████▏     | 2.68GB / 6.31GB,  143MB/s
#
# Processing Files (0 / 1)                :  43%|████▎     | 2.71GB / 6.31GB,  143MB/s
#
# Processing Files (0 / 1)                :  43%|████▎     | 2.73GB / 6.31GB,  143MB/s
#
# Processing Files (0 / 1)                :  44%|████▍     | 2.76GB / 6.31GB,  142MB/s
#
# Processing Files (0 / 1)                :  44%|████▍     | 2.79GB / 6.31GB,  142MB/s
#
# Processing Files (0 / 1)                :  45%|████▍     | 2.82GB / 6.31GB,  142MB/s
#
# Processing Files (0 / 1)                :  45%|████▌     | 2.84GB / 6.31GB,  142MB/s
#
# Processing Files (0 / 1)                :  46%|████▌     | 2.88GB / 6.31GB,  143MB/s
#
# Processing Files (0 / 1)                :  46%|████▌     | 2.91GB / 6.31GB,  143MB/s
#
# Processing Files (0 / 1)                :  47%|████▋     | 2.94GB / 6.31GB,  143MB/s
#
# Processing Files (0 / 1)                :  47%|████▋     | 2.96GB / 6.31GB,  142MB/s
#
# Processing Files (0 / 1)                :  47%|████▋     | 2.99GB / 6.31GB,  141MB/s
#
# Processing Files (0 / 1)                :  48%|████▊     | 3.01GB / 6.31GB,  141MB/s
#
# Processing Files (0 / 1)                :  48%|████▊     | 3.05GB / 6.31GB,  142MB/s
#
# Processing Files (0 / 1)                :  49%|████▊     | 3.07GB / 6.31GB,  142MB/s
#
# Processing Files (0 / 1)                :  49%|████▉     | 3.10GB / 6.31GB,  142MB/s
#
# Processing Files (0 / 1)                :  50%|████▉     | 3.13GB / 6.31GB,  142MB/s
#
# Processing Files (0 / 1)                :  50%|█████     | 3.15GB / 6.31GB,  141MB/s
#
# Processing Files (0 / 1)                :  51%|█████     | 3.19GB / 6.31GB,  142MB/s
#
# Processing Files (0 / 1)                :  51%|█████     | 3.21GB / 6.31GB,  142MB/s
#
# Processing Files (0 / 1)                :  51%|█████▏    | 3.24GB / 6.31GB,  141MB/s
#
# Processing Files (0 / 1)                :  52%|█████▏    | 3.27GB / 6.31GB,  142MB/s
#
# Processing Files (0 / 1)                :  52%|█████▏    | 3.30GB / 6.31GB,  141MB/s
#
# Processing Files (0 / 1)                :  53%|█████▎    | 3.32GB / 6.31GB,  141MB/s
#
# Processing Files (0 / 1)                :  53%|█████▎    | 3.36GB / 6.31GB,  141MB/s
#
# Processing Files (0 / 1)                :  54%|█████▎    | 3.38GB / 6.31GB,  141MB/s
#
# Processing Files (0 / 1)                :  54%|█████▍    | 3.41GB / 6.31GB,  141MB/s
#
# Processing Files (0 / 1)                :  54%|█████▍    | 3.43GB / 6.31GB,  141MB/s
#
# Processing Files (0 / 1)                :  55%|█████▍    | 3.46GB / 6.31GB,  141MB/s
#
# Processing Files (0 / 1)                :  55%|█████▌    | 3.49GB / 6.31GB,  141MB/s
#
# Processing Files (0 / 1)                :  56%|█████▌    | 3.52GB / 6.31GB,  141MB/s
#
# Processing Files (0 / 1)                :  56%|█████▋    | 3.55GB / 6.31GB,  141MB/s
#
# Processing Files (0 / 1)                :  57%|█████▋    | 3.58GB / 6.31GB,  142MB/s
#
# Processing Files (0 / 1)                :  57%|█████▋    | 3.61GB / 6.31GB,  141MB/s
#
# Processing Files (0 / 1)                :  58%|█████▊    | 3.64GB / 6.31GB,  141MB/s
#
# Processing Files (0 / 1)                :  58%|█████▊    | 3.67GB / 6.31GB,  141MB/s
#
# Processing Files (0 / 1)                :  59%|█████▊    | 3.70GB / 6.31GB,  141MB/s
#
# Processing Files (0 / 1)                :  59%|█████▉    | 3.73GB / 6.31GB,  142MB/s
#
# Processing Files (0 / 1)                :  60%|█████▉    | 3.76GB / 6.31GB,  142MB/s
#
# Processing Files (0 / 1)                :  60%|██████    | 3.79GB / 6.31GB,  143MB/s
#
# Processing Files (0 / 1)                :  61%|██████    | 3.82GB / 6.31GB,  143MB/s
#
# Processing Files (0 / 1)                :  61%|██████    | 3.84GB / 6.31GB,  143MB/s
#
# Processing Files (0 / 1)                :  61%|██████▏   | 3.87GB / 6.31GB,  143MB/s
#
# Processing Files (0 / 1)                :  62%|██████▏   | 3.89GB / 6.31GB,  142MB/s
#
# Processing Files (0 / 1)                :  62%|██████▏   | 3.92GB / 6.31GB,  141MB/s
#
# Processing Files (0 / 1)                :  63%|██████▎   | 3.95GB / 6.31GB,  142MB/s
#
# Processing Files (0 / 1)                :  63%|██████▎   | 3.98GB / 6.31GB,  142MB/s
#
# Processing Files (0 / 1)                :  64%|██████▎   | 4.01GB / 6.31GB,  142MB/s
#
# Processing Files (0 / 1)                :  64%|██████▍   | 4.04GB / 6.31GB,  142MB/s
#
# Processing Files (0 / 1)                :  65%|██████▍   | 4.07GB / 6.31GB,  142MB/s
#
# Processing Files (0 / 1)                :  65%|██████▌   | 4.10GB / 6.31GB,  142MB/s
#
# Processing Files (0 / 1)                :  65%|██████▌   | 4.13GB / 6.31GB,  142MB/s
#
# Processing Files (0 / 1)                :  66%|██████▌   | 4.16GB / 6.31GB,  142MB/s
#
# Processing Files (0 / 1)                :  67%|██████▋   | 4.19GB / 6.31GB,  143MB/s
#
# Processing Files (0 / 1)                :  67%|██████▋   | 4.22GB / 6.31GB,  143MB/s
#
# Processing Files (0 / 1)                :  67%|██████▋   | 4.25GB / 6.31GB,  144MB/s
#
# Processing Files (0 / 1)                :  68%|██████▊   | 4.28GB / 6.31GB,  143MB/s
#
# Processing Files (0 / 1)                :  68%|██████▊   | 4.31GB / 6.31GB,  144MB/s
#
# Processing Files (0 / 1)                :  69%|██████▉   | 4.35GB / 6.31GB,  144MB/s
#
# Processing Files (0 / 1)                :  69%|██████▉   | 4.38GB / 6.31GB,  144MB/s
#
# Processing Files (0 / 1)                :  70%|██████▉   | 4.40GB / 6.31GB,  144MB/s
#
# Processing Files (0 / 1)                :  70%|███████   | 4.43GB / 6.31GB,  144MB/s
#
# Processing Files (0 / 1)                :  71%|███████   | 4.46GB / 6.31GB,  145MB/s
#
# Processing Files (0 / 1)                :  71%|███████▏  | 4.50GB / 6.31GB,  146MB/s
#
# Processing Files (0 / 1)                :  72%|███████▏  | 4.53GB / 6.31GB,  146MB/s
#
# Processing Files (0 / 1)                :  72%|███████▏  | 4.55GB / 6.31GB,  146MB/s
#
# Processing Files (0 / 1)                :  73%|███████▎  | 4.59GB / 6.31GB,  146MB/s
#
# Processing Files (0 / 1)                :  73%|███████▎  | 4.62GB / 6.31GB,  146MB/s
#
# Processing Files (0 / 1)                :  74%|███████▎  | 4.65GB / 6.31GB,  146MB/s
#
# Processing Files (0 / 1)                :  74%|███████▍  | 4.68GB / 6.31GB,  146MB/s
#
# Processing Files (0 / 1)                :  75%|███████▍  | 4.71GB / 6.31GB,  146MB/s
#
# Processing Files (0 / 1)                :  75%|███████▌  | 4.74GB / 6.31GB,  147MB/s
#
# Processing Files (0 / 1)                :  76%|███████▌  | 4.77GB / 6.31GB,  147MB/s
#
# Processing Files (0 / 1)                :  76%|███████▌  | 4.80GB / 6.31GB,  147MB/s
#
# Processing Files (0 / 1)                :  77%|███████▋  | 4.83GB / 6.31GB,  148MB/s
#
# Processing Files (0 / 1)                :  77%|███████▋  | 4.86GB / 6.31GB,  147MB/s
#
# Processing Files (0 / 1)                :  78%|███████▊  | 4.89GB / 6.31GB,  148MB/s
#
# Processing Files (0 / 1)                :  78%|███████▊  | 4.92GB / 6.31GB,  148MB/s
#
# Processing Files (0 / 1)                :  78%|███████▊  | 4.94GB / 6.31GB,  148MB/s
#
# Processing Files (0 / 1)                :  79%|███████▉  | 4.97GB / 6.31GB,  148MB/s
#
# Processing Files (0 / 1)                :  79%|███████▉  | 5.00GB / 6.31GB,  148MB/s
#
# Processing Files (0 / 1)                :  80%|███████▉  | 5.03GB / 6.31GB,  148MB/s
#
# Processing Files (0 / 1)                :  80%|████████  | 5.06GB / 6.31GB,  148MB/s
#
# Processing Files (0 / 1)                :  81%|████████  | 5.08GB / 6.31GB,  147MB/s
#
# Processing Files (0 / 1)                :  81%|████████  | 5.12GB / 6.31GB,  148MB/s
#
# Processing Files (0 / 1)                :  82%|████████▏ | 5.14GB / 6.31GB,  147MB/s
#
# Processing Files (0 / 1)                :  82%|████████▏ | 5.18GB / 6.31GB,  148MB/s
#
# Processing Files (0 / 1)                :  82%|████████▏ | 5.20GB / 6.31GB,  147MB/s
#
# Processing Files (0 / 1)                :  83%|████████▎ | 5.23GB / 6.31GB,  146MB/s
#
# Processing Files (0 / 1)                :  83%|████████▎ | 5.25GB / 6.31GB,  146MB/s
#
# Processing Files (0 / 1)                :  84%|████████▎ | 5.28GB / 6.31GB,  146MB/s
#
# Processing Files (0 / 1)                :  84%|████████▍ | 5.30GB / 6.31GB,  146MB/s
#
# Processing Files (0 / 1)                :  85%|████████▍ | 5.34GB / 6.31GB,  146MB/s
#
# Processing Files (0 / 1)                :  85%|████████▌ | 5.36GB / 6.31GB,  146MB/s
#
# Processing Files (0 / 1)                :  85%|████████▌ | 5.39GB / 6.31GB,  146MB/s
#
# Processing Files (0 / 1)                :  86%|████████▌ | 5.41GB / 6.31GB,  146MB/s
#
# Processing Files (0 / 1)                :  86%|████████▋ | 5.44GB / 6.31GB,  146MB/s
#
# Processing Files (0 / 1)                :  87%|████████▋ | 5.47GB / 6.31GB,  146MB/s
#
# Processing Files (0 / 1)                :  87%|████████▋ | 5.50GB / 6.31GB,  146MB/s
#
# Processing Files (0 / 1)                :  88%|████████▊ | 5.54GB / 6.31GB,  146MB/s
#
# Processing Files (0 / 1)                :  88%|████████▊ | 5.57GB / 6.31GB,  147MB/s
#
# Processing Files (0 / 1)                :  89%|████████▉ | 5.60GB / 6.31GB,  147MB/s
#
# Processing Files (0 / 1)                :  89%|████████▉ | 5.64GB / 6.31GB,  148MB/s
#
# Processing Files (0 / 1)                :  90%|████████▉ | 5.67GB / 6.31GB,  148MB/s
#
# Processing Files (0 / 1)                :  90%|█████████ | 5.70GB / 6.31GB,  147MB/s
#
# Processing Files (0 / 1)                :  91%|█████████ | 5.73GB / 6.31GB,  148MB/s
#
# Processing Files (0 / 1)                :  91%|█████████▏| 5.76GB / 6.31GB,  148MB/s
#
# Processing Files (0 / 1)                :  92%|█████████▏| 5.80GB / 6.31GB,  149MB/s
#
# Processing Files (0 / 1)                :  92%|█████████▏| 5.82GB / 6.31GB,  148MB/s
#
# Processing Files (0 / 1)                :  93%|█████████▎| 5.86GB / 6.31GB,  148MB/s
#
# Processing Files (0 / 1)                :  93%|█████████▎| 5.89GB / 6.31GB,  148MB/s
#
# Processing Files (0 / 1)                :  94%|█████████▍| 5.91GB / 6.31GB,  148MB/s
#
# Processing Files (0 / 1)                :  94%|█████████▍| 5.95GB / 6.31GB,  149MB/s
#
# Processing Files (0 / 1)                :  95%|█████████▍| 5.98GB / 6.31GB,  149MB/s
#
# Processing Files (0 / 1)                :  95%|█████████▌| 6.01GB / 6.31GB,  149MB/s
#
# Processing Files (0 / 1)                :  96%|█████████▌| 6.04GB / 6.31GB,  148MB/s
#
# Processing Files (0 / 1)                :  96%|█████████▋| 6.07GB / 6.31GB,  149MB/s
#
# Processing Files (0 / 1)                :  97%|█████████▋| 6.10GB / 6.31GB,  148MB/s
#
# Processing Files (0 / 1)                :  97%|█████████▋| 6.13GB / 6.31GB,  148MB/s
#
# Processing Files (0 / 1)                :  98%|█████████▊| 6.17GB / 6.31GB,  149MB/s
#
# Processing Files (0 / 1)                :  98%|█████████▊| 6.19GB / 6.31GB,  148MB/s
#
# Processing Files (0 / 1)                :  99%|█████████▊| 6.22GB / 6.31GB,  149MB/s
#
# Processing Files (0 / 1)                :  99%|█████████▉| 6.25GB / 6.31GB,  148MB/s
#
# Processing Files (0 / 1)                : 100%|█████████▉| 6.28GB / 6.31GB,  148MB/s
#
# Processing Files (1 / 1)                : 100%|██████████| 6.31GB / 6.31GB,  148MB/s
#
#   /home/jovyan/work/data/train.csv      : 100%|██████████| 6.31GB / 6.31GB
#
#   /home/jovyan/work/data/train.csv      : 100%|██████████| 6.31GB / 6.31GB
#
#   /home/jovyan/work/data/train.csv      : 100%|██████████| 6.31GB / 6.31GB
#
#   /home/jovyan/work/data/train.csv      : 100%|██████████| 6.31GB / 6.31GB
#
# Processing Files (1 / 1)                : 100%|██████████| 6.31GB / 6.31GB,  136MB/s
# New Data Upload                         : |          |  0.00B /  0.00B,  0.00B/s
#   /home/jovyan/work/data/train.csv      : 100%|██████████| 6.31GB / 6.31GB
# CommitInfo(commit_url='https://huggingface.co/datasets/maksim2000153/aijk2/commit/1d435d4f92c6f49e643ed3166e642365e49ed56a', commit_message='Upload folder using huggingface_hub', commit_description='', oid='1d435d4f92c6f49e643ed3166e642365e49ed56a', pr_url=None, repo_url=RepoUrl('https://huggingface.co/datasets/maksim2000153/aijk2', endpoint='https://huggingface.co', repo_type='dataset', repo_id='maksim2000153/aijk2'), pr_revision=None, pr_num=None)

# %%
data_files = {"train": "data/train.csv", "test": "data/test.csv", "sample_submission": "data/sample_submission.csv"}
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 2
#       1 data_files = {"train": "data/train.csv", "test": "data/test.csv", "sample_submission": "data/sample_submission.csv"}
# ----> 2 dataset = load_dataset("maksim2000153/aijk2", data_files=data_files)
#
# File /opt/conda/lib/python3.11/site-packages/datasets/load.py:1392, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, keep_in_memory, save_infos, revision, token, streaming, num_proc, storage_options, **config_kwargs)
#    1387 verification_mode = VerificationMode(
#    1388     (verification_mode or VerificationMode.BASIC_CHECKS) if not save_infos else VerificationMode.ALL_CHECKS
#    1389 )
#    1391 # Create a dataset builder
# -> 1392 builder_instance = load_dataset_builder(
#    1393     path=path,
#    1394     name=name,
#    1395     data_dir=data_dir,
#    1396     data_files=data_files,
#    1397     cache_dir=cache_dir,
#    1398     features=features,
#    1399     download_config=download_config,
#    1400     download_mode=download_mode,
#    1401     revision=revision,
#    1402     token=token,
#    1403     storage_options=storage_options,
#    1404     **config_kwargs,
#    1405 )
#    1407 # Return iterable dataset in case of streaming
#    1408 if streaming:
#
# File /opt/conda/lib/python3.11/site-packages/datasets/load.py:1132, in load_dataset_builder(path, name, data_dir, data_files, cache_dir, features, download_config, download_mode, revision, token, storage_options, **config_kwargs)
#    1130 if features is not None:
#    1131     features = _fix_for_backward_compatible_features(features)
# -> 1132 dataset_module = dataset_module_factory(
#    1133     path,
#    1134     revision=revision,
#    1135     download_config=download_config,
#    1136     download_mode=download_mode,
#    1137     data_dir=data_dir,
#    1138     data_files=data_files,
#    1139     cache_dir=cache_dir,
#    1140 )
#    1141 # Get dataset builder class
#    1142 builder_kwargs = dataset_module.builder_kwargs
#
# File /opt/conda/lib/python3.11/site-packages/datasets/load.py:1027, in dataset_module_factory(path, revision, download_config, download_mode, data_dir, data_files, cache_dir, **download_kwargs)
#    1025                 raise e1 from None
#    1026             if isinstance(e1, FileNotFoundError):
# -> 1027                 raise FileNotFoundError(
#    1028                     f"Couldn't find any data file at {relative_to_absolute_path(path)}. "
#    1029                     f"Couldn't find '{path}' on the Hugging Face Hub either: {type(e1).__name__}: {e1}"
#    1030                 ) from None
#    1031             raise e1 from None
#    1032 else:
#
# FileNotFoundError: Couldn't find any data file at /home/jovyan/work/maksim2000153/aijk2. Couldn't find 'maksim2000153/aijk2' on the Hugging Face Hub either: FileNotFoundError: Unable to find 'hf://datasets/maksim2000153/aijk2@24e041f047c39ebfa4d00bc91b04e38f804a0bb3/data/train.csv' with any supported extension ['.csv', '.tsv', '.json', '.jsonl', '.ndjson', '.parquet', '.geoparquet', '.gpq', '.arrow', '.txt', '.tar', '.xml', '.blp', '.bmp', '.dib', '.bufr', '.cur', '.pcx', '.dcx', '.dds', '.ps', '.eps', '.fit', '.fits', '.fli', '.flc', '.ftc', '.ftu', '.gbr', '.gif', '.grib', '.png', '.apng', '.jp2', '.j2k', '.jpc', '.jpf', '.jpx', '.j2c', '.icns', '.ico', '.im', '.iim', '.tif', '.tiff', '.jfif', '.jpe', '.jpg', '.jpeg', '.mpg', '.mpeg', '.msp', '.pcd', '.pxr', '.pbm', '.pgm', '.ppm', '.pnm', '.psd', '.bw', '.rgb', '.rgba', '.sgi', '.ras', '.tga', '.icb', '.vda', '.vst', '.webp', '.wmf', '.emf', '.xbm', '.xpm', '.BLP', '.BMP', '.DIB', '.BUFR', '.CUR', '.PCX', '.DCX', '.DDS', '.PS', '.EPS', '.FIT', '.FITS', '.FLI', '.FLC', '.FTC', '.FTU', '.GBR', '.GIF', '.GRIB', '.PNG', '.APNG', '.JP2', '.J2K', '.JPC', '.JPF', '.JPX', '.J2C', '.ICNS', '.ICO', '.IM', '.IIM', '.TIF', '.TIFF', '.JFIF', '.JPE', '.JPG', '.JPEG', '.MPG', '.MPEG', '.MSP', '.PCD', '.PXR', '.PBM', '.PGM', '.PPM', '.PNM', '.PSD', '.BW', '.RGB', '.RGBA', '.SGI', '.RAS', '.TGA', '.ICB', '.VDA', '.VST', '.WEBP', '.WMF', '.EMF', '.XBM', '.XPM', '.aiff', '.au', '.avr', '.caf', '.flac', '.htk', '.svx', '.mat4', '.mat5', '.mpc2k', '.ogg', '.paf', '.pvf', '.raw', '.rf64', '.sd2', '.sds', '.ircam', '.voc', '.w64', '.wav', '.nist', '.wavex', '.wve', '.xi', '.mp3', '.opus', '.3gp', '.3g2', '.avi', '.asf', '.flv', '.mp4', '.mov', '.m4v', '.mkv', '.webm', '.f4v', '.wmv', '.wma', '.ogm', '.mxf', '.nut', '.AIFF', '.AU', '.AVR', '.CAF', '.FLAC', '.HTK', '.SVX', '.MAT4', '.MAT5', '.MPC2K', '.OGG', '.PAF', '.PVF', '.RAW', '.RF64', '.SD2', '.SDS', '.IRCAM', '.VOC', '.W64', '.WAV', '.NIST', '.WAVEX', '.WVE', '.XI', '.MP3', '.OPUS', '.3GP', '.3G2', '.AVI', '.ASF', '.FLV', '.MP4', '.MOV', '.M4V', '.MKV', '.WEBM', '.F4V', '.WMV', '.WMA', '.OGM', '.MXF', '.NUT', '.pdf', '.PDF', '.zip']

# %%
import os

# %%
from huggingface_hub import HfApi

api = HfApi(token=os.getenv("HF_TOKEN"))
api.upload_folder(
    folder_path=".",
    repo_id="maksim2000153/aijk2",
    repo_type="dataset",
)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File /opt/conda/lib/python3.11/site-packages/huggingface_hub/utils/_http.py:409, in hf_raise_for_status(response, endpoint_name)
#     408 try:
# --> 409     response.raise_for_status()
#     410 except HTTPError as e:
#
# File /opt/conda/lib/python3.11/site-packages/requests/models.py:1026, in Response.raise_for_status(self)
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 401 Client Error: Unauthorized for url: https://huggingface.co/api/datasets/maksim2000153/aijk2/preupload/main
#
# The above exception was the direct cause of the following exception:
#
# RepositoryNotFoundError                   Traceback (most recent call last)
# Cell In[10], line 4
#       1 from huggingface_hub import HfApi
#       3 api = HfApi(token=os.getenv("HF_TOKEN"))
# ----> 4 api.upload_folder(
#       5     folder_path=".",
#       6     repo_id="maksim2000153/aijk2",
#       7     repo_type="dataset",
#       8 )
#
# File /opt/conda/lib/python3.11/site-packages/huggingface_hub/utils/_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/huggingface_hub/hf_api.py:1669, in future_compatible.<locals>._inner(self, *args, **kwargs)
#    1666     return self.run_as_future(fn, self, *args, **kwargs)
#    1668 # Otherwise, call the function normally
# -> 1669 return fn(self, *args, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/huggingface_hub/hf_api.py:4982, in HfApi.upload_folder(self, repo_id, folder_path, path_in_repo, commit_message, commit_description, token, repo_type, revision, create_pr, parent_commit, allow_patterns, ignore_patterns, delete_patterns, run_as_future)
#    4978 commit_operations = delete_operations + add_operations
#    4980 commit_message = commit_message or "Upload folder using huggingface_hub"
# -> 4982 commit_info = self.create_commit(
#    4983     repo_type=repo_type,
#    4984     repo_id=repo_id,
#    4985     operations=commit_operations,
#    4986     commit_message=commit_message,
#    4987     commit_description=commit_description,
#    4988     token=token,
#    4989     revision=revision,
#    4990     create_pr=create_pr,
#    4991     parent_commit=parent_commit,
#    4992 )
#    4994 # Create url to uploaded folder (for legacy return value)
#    4995 if create_pr and commit_info.pr_url is not None:
#
# File /opt/conda/lib/python3.11/site-packages/huggingface_hub/utils/_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/huggingface_hub/hf_api.py:1669, in future_compatible.<locals>._inner(self, *args, **kwargs)
#    1666     return self.run_as_future(fn, self, *args, **kwargs)
#    1668 # Otherwise, call the function normally
# -> 1669 return fn(self, *args, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/huggingface_hub/hf_api.py:4239, in HfApi.create_commit(self, repo_id, operations, commit_message, commit_description, token, repo_type, revision, create_pr, num_threads, parent_commit, run_as_future)
#    4236 # If updating twice the same file or update then delete a file in a single commit
#    4237 _warn_on_overwriting_operations(operations)
# -> 4239 self.preupload_lfs_files(
#    4240     repo_id=repo_id,
#    4241     additions=additions,
#    4242     token=token,
#    4243     repo_type=repo_type,
#    4244     revision=unquoted_revision,  # first-class methods take unquoted revision
#    4245     create_pr=create_pr,
#    4246     num_threads=num_threads,
#    4247     free_memory=False,  # do not remove `CommitOperationAdd.path_or_fileobj` on LFS files for "normal" users
#    4248 )
#    4250 files_to_copy = _fetch_files_to_copy(
#    4251     copies=copies,
#    4252     repo_type=repo_type,
#    (...)
#    4256     endpoint=self.endpoint,
#    4257 )
#    4258 # Remove no-op operations (files that have not changed)
#
# File /opt/conda/lib/python3.11/site-packages/huggingface_hub/hf_api.py:4465, in HfApi.preupload_lfs_files(self, repo_id, additions, token, repo_type, revision, create_pr, num_threads, free_memory, gitignore_content)
#    4463 if len(additions_no_upload_mode) > 0:
#    4464     try:
# -> 4465         _fetch_upload_modes(
#    4466             additions=additions_no_upload_mode,
#    4467             repo_type=repo_type,
#    4468             repo_id=repo_id,
#    4469             headers=headers,
#    4470             revision=revision,
#    4471             endpoint=self.endpoint,
#    4472             create_pr=create_pr or False,
#    4473             gitignore_content=gitignore_content,
#    4474         )
#    4475     except RepositoryNotFoundError as e:
#    4476         e.append_to_message(_CREATE_COMMIT_NO_REPO_ERROR_MESSAGE)
#
# File /opt/conda/lib/python3.11/site-packages/huggingface_hub/utils/_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/huggingface_hub/_commit_api.py:692, in _fetch_upload_modes(additions, repo_type, repo_id, headers, revision, endpoint, create_pr, gitignore_content)
#     684     payload["gitIgnore"] = gitignore_content
#     686 resp = get_session().post(
#     687     f"{endpoint}/api/{repo_type}s/{repo_id}/preupload/{revision}",
#     688     json=payload,
#     689     headers=headers,
#     690     params={"create_pr": "1"} if create_pr else None,
#     691 )
# --> 692 hf_raise_for_status(resp)
#     693 preupload_info = _validate_preupload_info(resp.json())
#     694 upload_modes.update(**{file["path"]: file["uploadMode"] for file in preupload_info["files"]})
#
# File /opt/conda/lib/python3.11/site-packages/huggingface_hub/utils/_http.py:459, in hf_raise_for_status(response, endpoint_name)
#     438 elif error_code == "RepoNotFound" or (
#     439     response.status_code == 401
#     440     and error_message != "Invalid credentials in Authorization header"
#    (...)
#     448     # => for now, we process them as `RepoNotFound` anyway.
#     449     # See https://gist.github.com/Wauplin/46c27ad266b15998ce56a6603796f0b9
#     450     message = (
#     451         f"{response.status_code} Client Error."
#     452         + "\n\n"
#    (...)
#     457         " https://huggingface.co/docs/huggingface_hub/authentication"
#     458     )
# --> 459     raise _format(RepositoryNotFoundError, message, response) from e
#     461 elif response.status_code == 400:
#     462     message = (
#     463         f"\n\nBad request for {endpoint_name} endpoint:" if endpoint_name is not None else "\n\nBad request:"
#     464     )
#
# RepositoryNotFoundError: 401 Client Error. (Request ID: Root=1-689b1cfb-708c92f5732c975955381579;9cf4a1b7-d1e1-4801-bd83-76a459d5ff19)
#
# Repository Not Found for url: https://huggingface.co/api/datasets/maksim2000153/aijk2/preupload/main.
# Please make sure you specified the correct `repo_id` and `repo_type`.
# If you are trying to access a private or gated repo, make sure you are authenticated. For more details, see https://huggingface.co/docs/huggingface_hub/authentication
# Invalid username or password.
# Note: Creating a commit assumes that the repo already exists on the Huggingface Hub. Please use `create_repo` if it's not the case.
